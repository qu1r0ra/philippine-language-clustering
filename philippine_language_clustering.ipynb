# %% [markdown]
# <a href="https://colab.research.google.com/github/qu1r0ra/philippine-language-clustering/blob/main/philippine_language_clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Repository Setup
#
# First, let us clone the GitHub repository containing code which our notebook relies on.
#
# The primary reason as to why the authors decided to externalize most code via a repository is to integrate software engineering principles and practices into the project, thereby improving its cleanliness and quality.
#
# Maintaining a GitHub repository alongside a Jupyter notebook (as opposed to relying solely on the notebook) allows for better code organization and version control. Code snippets for high-level tasks (e.g., preprocessing data, computing for distance) can be refactored to files, making it easier to debug and modify code. Version control for these scripts is a given as we are utilizing Git.
#
# In a sense, this notebook serves as a 'presentation layer' which simply utilizes functions and classes abstracted by various Python scripts in the said GitHub repository.

# %%
import os

repo_url = "https://github.com/qu1r0ra/philippine-language-clustering.git"
repo_dir = "philippine-language-clustering"
branch = "main"

# Change to the working directory in Google Colab: /content
# %cd /content

# Remove previous clone
if os.path.exists(repo_dir):
  print(f"\nRemoving old repo folder '{repo_dir}' to ensure a clean clone...")
  # !rm -rf {repo_dir}
else:
  print(f"\nNo repo folder '{repo_dir}' found.")

# Clone the specified branch
print(f"\nCloning branch {branch} from repository...")
# !git clone --branch {branch} --single-branch {repo_url} {repo_dir}

# Move into the cloned directory
# %cd {repo_dir}

# Install or upgrade uv
print("\nInstalling/Upgrading uv...")
# !pip install --upgrade uv --quiet

# Install dependencies using uv
if os.path.exists("pyproject.toml"):
  print("\nInstalling dependencies with uv...")
  # !uv sync --quiet
else:
  print("\nNo pyproject.toml found — skipping uv install.")

print(f"\nSetup complete!")
# Out:
# /content
#
# Removing old repo folder 'philippine-language-clustering' to ensure a clean clone...
#
# Cloning branch main from repository...
# Cloning into 'philippine-language-clustering'...
# remote: Enumerating objects: 79, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 79 (delta 19), reused 8 (delta 6), pack-reused 50 (from 1)
# Receiving objects: 100% (79/79), 307.08 KiB | 7.31 MiB/s, done.
# Resolving deltas: 100% (32/32), done.
# /content/philippine-language-clustering
#
# Installing/Upgrading uv...
#
# Installing dependencies with uv...
#
# Setup complete!

# %% [markdown]
# ## Data Setup
#
# 1. Create a `data` folder and a `zipped` folder inside `data`.
# 2. Download `segmented.zip` from [this GDrive link](https://drive.google.com/drive/folders/1hKNLOayge7rvjx5LNMzHrMoGJY7gTeAT?usp=sharing) and upload it to `data/zipped`.
# 3. Run the script below to unzip the segmented data.

# %%
import zipfile

data_root = "/content/data"
zip_dir = os.path.join(data_root, "zipped")
unzipped_dir = os.path.join(data_root, "unzipped")

os.makedirs(zip_dir, exist_ok=True)
os.makedirs(unzipped_dir, exist_ok=True)

# Loop through all zip files and extract them to the unzipped folder
for zip_file in os.listdir(zip_dir):
    if zip_file.endswith(".zip"):
        zip_path = os.path.join(zip_dir, zip_file)
        extract_folder_name = os.path.splitext(zip_file)[0]
        extract_path = os.path.join(unzipped_dir, extract_folder_name)
        os.makedirs(extract_path, exist_ok=True)

        print(f"\nExtracting {zip_file} → {extract_folder_name}/ ...")
        with zipfile.ZipFile(zip_path, "r") as zf:
            zf.extractall(extract_path)
        print("\nDone!")

print("\nAll archives extracted.")
# !ls -R {unzipped_dir}
# Out:
# Extracting segmented.zip → segmented/ ...
#
# Done!
#
# All archives extracted.
# /content/data/unzipped:
# segmented
#
# /content/data/unzipped/segmented:
# by_sentence  by_verse
#
# /content/data/unzipped/segmented/by_sentence:
# Bikolano  Chavacano  Isnag   Kalinga	Kapampangan   Sambal   Tagalog	Yakan
# Cebuano   Ilokano    Ivatan  Kankanaey	Pangasinense  Spanish  Tausug	Yami
#
# /content/data/unzipped/segmented/by_sentence/Bikolano:
# MBBBIK92_1CH_raw.csv  MBBBIK92_ECC_raw.csv  MBBBIK92_LUK_raw.csv
# MBBBIK92_1CH_raw.txt  MBBBIK92_ECC_raw.txt  MBBBIK92_LUK_raw.txt
# MBBBIK92_1CO_raw.csv  MBBBIK92_EPH_raw.csv  MBBBIK92_MAL_raw.csv
# MBBBIK92_1CO_raw.txt  MBBBIK92_EPH_raw.txt  MBBBIK92_MAL_raw.txt
# MBBBIK92_1JN_raw.csv  MBBBIK92_EST_raw.csv  MBBBIK92_MAT_raw.csv
# MBBBIK92_1JN_raw.txt  MBBBIK92_EST_raw.txt  MBBBIK92_MAT_raw.txt
# MBBBIK92_1KI_raw.csv  MBBBIK92_EXO_raw.csv  MBBBIK92_MIC_raw.csv
# MBBBIK92_1KI_raw.txt  MBBBIK92_EXO_raw.txt  MBBBIK92_MIC_raw.txt
# MBBBIK92_1MA_raw.csv  MBBBIK92_EZK_raw.csv  MBBBIK92_MRK_raw.csv
# MBBBIK92_1MA_raw.txt  MBBBIK92_EZK_raw.txt  MBBBIK92_MRK_raw.txt
# MBBBIK92_1PE_raw.csv  MBBBIK92_EZR_raw.csv  MBBBIK92_NAM_raw.csv
# MBBBIK92_1PE_raw.txt  MBBBIK92_EZR_raw.txt  MBBBIK92_NAM_raw.txt
# MBBBIK92_1SA_raw.csv  MBBBIK92_GAL_raw.csv  MBBBIK92_NEH_raw.csv
# MBBBIK92_1SA_raw.txt  MBBBIK92_GAL_raw.txt  MBBBIK92_NEH_raw.txt
# MBBBIK92_1TH_raw.csv  MBBBIK92_GEN_raw.csv  MBBBIK92_NUM_raw.csv
# MBBBIK92_1TH_raw.txt  MBBBIK92_GEN_raw.txt  MBBBIK92_NUM_raw.txt
# MBBBIK92_1TI_raw.csv  MBBBIK92_HAB_raw.csv  MBBBIK92_OBA_raw.csv
# MBBBIK92_1TI_raw.txt  MBBBIK92_HAB_raw.txt  MBBBIK92_OBA_raw.txt
# MBBBIK92_2CH_raw.csv  MBBBIK92_HAG_raw.csv  MBBBIK92_PHM_raw.csv
# MBBBIK92_2CH_raw.txt  MBBBIK92_HAG_raw.txt  MBBBIK92_PHM_raw.txt
# MBBBIK92_2CO_raw.csv  MBBBIK92_HEB_raw.csv  MBBBIK92_PHP_raw.csv
# MBBBIK92_2CO_raw.txt  MBBBIK92_HEB_raw.txt  MBBBIK92_PHP_raw.txt
# MBBBIK92_2JN_raw.csv  MBBBIK92_HOS_raw.csv  MBBBIK92_PRO_raw.csv
# MBBBIK92_2JN_raw.txt  MBBBIK92_HOS_raw.txt  MBBBIK92_PRO_raw.txt
# MBBBIK92_2KI_raw.csv  MBBBIK92_ISA_raw.csv  MBBBIK92_PSA_raw.csv
# MBBBIK92_2KI_raw.txt  MBBBIK92_ISA_raw.txt  MBBBIK92_PSA_raw.txt
# MBBBIK92_2MA_raw.csv  MBBBIK92_JAS_raw.csv  MBBBIK92_REV_raw.csv
# MBBBIK92_2MA_raw.txt  MBBBIK92_JAS_raw.txt  MBBBIK92_REV_raw.txt
# MBBBIK92_2PE_raw.csv  MBBBIK92_JDG_raw.csv  MBBBIK92_ROM_raw.csv
# MBBBIK92_2PE_raw.txt  MBBBIK92_JDG_raw.txt  MBBBIK92_ROM_raw.txt
# MBBBIK92_2SA_raw.csv  MBBBIK92_JDT_raw.csv  MBBBIK92_RUT_raw.csv
# MBBBIK92_2SA_raw.txt  MBBBIK92_JDT_raw.txt  MBBBIK92_RUT_raw.txt
# MBBBIK92_2TH_raw.csv  MBBBIK92_JER_raw.csv  MBBBIK92_S3Y_raw.csv
# MBBBIK92_2TH_raw.txt  MBBBIK92_JER_raw.txt  MBBBIK92_S3Y_raw.txt
# MBBBIK92_2TI_raw.csv  MBBBIK92_JHN_raw.csv  MBBBIK92_SIR_raw.csv
# MBBBIK92_2TI_raw.txt  MBBBIK92_JHN_raw.txt  MBBBIK92_SIR_raw.txt
# MBBBIK92_3JN_raw.csv  MBBBIK92_JOB_raw.csv  MBBBIK92_SNG_raw.csv
# MBBBIK92_3JN_raw.txt  MBBBIK92_JOB_raw.txt  MBBBIK92_SNG_raw.txt
# MBBBIK92_ACT_raw.csv  MBBBIK92_JOL_raw.csv  MBBBIK92_SUS_raw.csv
# MBBBIK92_ACT_raw.txt  MBBBIK92_JOL_raw.txt  MBBBIK92_SUS_raw.txt
# MBBBIK92_AMO_raw.csv  MBBBIK92_JON_raw.csv  MBBBIK92_TIT_raw.csv
# MBBBIK92_AMO_raw.txt  MBBBIK92_JON_raw.txt  MBBBIK92_TIT_raw.txt
# MBBBIK92_BAR_raw.csv  MBBBIK92_JOS_raw.csv  MBBBIK92_TOB_raw.csv
# MBBBIK92_BAR_raw.txt  MBBBIK92_JOS_raw.txt  MBBBIK92_TOB_raw.txt
# MBBBIK92_BEL_raw.csv  MBBBIK92_JUD_raw.csv  MBBBIK92_WIS_raw.csv
# MBBBIK92_BEL_raw.txt  MBBBIK92_JUD_raw.txt  MBBBIK92_WIS_raw.txt
# MBBBIK92_COL_raw.csv  MBBBIK92_LAM_raw.csv  MBBBIK92_ZEC_raw.csv
# MBBBIK92_COL_raw.txt  MBBBIK92_LAM_raw.txt  MBBBIK92_ZEC_raw.txt
# MBBBIK92_DAN_raw.csv  MBBBIK92_LEV_raw.csv  MBBBIK92_ZEP_raw.csv
# MBBBIK92_DAN_raw.txt  MBBBIK92_LEV_raw.txt  MBBBIK92_ZEP_raw.txt
# MBBBIK92_DEU_raw.csv  MBBBIK92_LJE_raw.csv
# MBBBIK92_DEU_raw.txt  MBBBIK92_LJE_raw.txt
#
# /content/data/unzipped/segmented/by_sentence/Cebuano:
# ABCEB_1CH_raw.csv  ABCEB_3JN_raw.txt  ABCEB_HOS_raw.csv  ABCEB_MIC_raw.txt
# ABCEB_1CH_raw.txt  ABCEB_ACT_raw.csv  ABCEB_HOS_raw.txt  ABCEB_MRK_raw.csv
# ABCEB_1CO_raw.csv  ABCEB_ACT_raw.txt  ABCEB_ISA_raw.csv  ABCEB_MRK_raw.txt
# ABCEB_1CO_raw.txt  ABCEB_AMO_raw.csv  ABCEB_ISA_raw.txt  ABCEB_NAM_raw.csv
# ABCEB_1JN_raw.csv  ABCEB_AMO_raw.txt  ABCEB_JAS_raw.csv  ABCEB_NAM_raw.txt
# ABCEB_1JN_raw.txt  ABCEB_COL_raw.csv  ABCEB_JAS_raw.txt  ABCEB_NEH_raw.csv
# ABCEB_1KI_raw.csv  ABCEB_COL_raw.txt  ABCEB_JDG_raw.csv  ABCEB_NEH_raw.txt
# ABCEB_1KI_raw.txt  ABCEB_DAN_raw.csv  ABCEB_JDG_raw.txt  ABCEB_NUM_raw.csv
# ABCEB_1PE_raw.csv  ABCEB_DAN_raw.txt  ABCEB_JER_raw.csv  ABCEB_NUM_raw.txt
# ABCEB_1PE_raw.txt  ABCEB_DEU_raw.csv  ABCEB_JER_raw.txt  ABCEB_OBA_raw.csv
# ABCEB_1SA_raw.csv  ABCEB_DEU_raw.txt  ABCEB_JHN_raw.csv  ABCEB_OBA_raw.txt
# ABCEB_1SA_raw.txt  ABCEB_ECC_raw.csv  ABCEB_JHN_raw.txt  ABCEB_PHM_raw.csv
# ABCEB_1TH_raw.csv  ABCEB_ECC_raw.txt  ABCEB_JOB_raw.csv  ABCEB_PHM_raw.txt
# ABCEB_1TH_raw.txt  ABCEB_EPH_raw.csv  ABCEB_JOB_raw.txt  ABCEB_PHP_raw.csv
# ABCEB_1TI_raw.csv  ABCEB_EPH_raw.txt  ABCEB_JOL_raw.csv  ABCEB_PHP_raw.txt
# ABCEB_1TI_raw.txt  ABCEB_EST_raw.csv  ABCEB_JOL_raw.txt  ABCEB_PRO_raw.csv
# ABCEB_2CH_raw.csv  ABCEB_EST_raw.txt  ABCEB_JON_raw.csv  ABCEB_PRO_raw.txt
# ABCEB_2CH_raw.txt  ABCEB_EXO_raw.csv  ABCEB_JON_raw.txt  ABCEB_PSA_raw.csv
# ABCEB_2CO_raw.csv  ABCEB_EXO_raw.txt  ABCEB_JOS_raw.csv  ABCEB_PSA_raw.txt
# ABCEB_2CO_raw.txt  ABCEB_EZK_raw.csv  ABCEB_JOS_raw.txt  ABCEB_REV_raw.csv
# ABCEB_2JN_raw.csv  ABCEB_EZK_raw.txt  ABCEB_JUD_raw.csv  ABCEB_REV_raw.txt
# ABCEB_2JN_raw.txt  ABCEB_EZR_raw.csv  ABCEB_JUD_raw.txt  ABCEB_ROM_raw.csv
# ABCEB_2KI_raw.csv  ABCEB_EZR_raw.txt  ABCEB_LAM_raw.csv  ABCEB_ROM_raw.txt
# ABCEB_2KI_raw.txt  ABCEB_GAL_raw.csv  ABCEB_LAM_raw.txt  ABCEB_RUT_raw.csv
# ABCEB_2PE_raw.csv  ABCEB_GAL_raw.txt  ABCEB_LEV_raw.csv  ABCEB_RUT_raw.txt
# ABCEB_2PE_raw.txt  ABCEB_GEN_raw.csv  ABCEB_LEV_raw.txt  ABCEB_SNG_raw.csv
# ABCEB_2SA_raw.csv  ABCEB_GEN_raw.txt  ABCEB_LUK_raw.csv  ABCEB_SNG_raw.txt
# ABCEB_2SA_raw.txt  ABCEB_HAB_raw.csv  ABCEB_LUK_raw.txt  ABCEB_TIT_raw.csv
# ABCEB_2TH_raw.csv  ABCEB_HAB_raw.txt  ABCEB_MAL_raw.csv  ABCEB_TIT_raw.txt
# ABCEB_2TH_raw.txt  ABCEB_HAG_raw.csv  ABCEB_MAL_raw.txt  ABCEB_ZEC_raw.csv
# ABCEB_2TI_raw.csv  ABCEB_HAG_raw.txt  ABCEB_MAT_raw.csv  ABCEB_ZEC_raw.txt
# ABCEB_2TI_raw.txt  ABCEB_HEB_raw.csv  ABCEB_MAT_raw.txt  ABCEB_ZEP_raw.csv
# ABCEB_3JN_raw.csv  ABCEB_HEB_raw.txt  ABCEB_MIC_raw.csv  ABCEB_ZEP_raw.txt
#
# /content/data/unzipped/segmented/by_sentence/Chavacano:
# CBKNT_1CO_raw.csv  CBKNT_2PE_raw.csv  CBKNT_GAL_raw.csv  CBKNT_MRK_raw.csv
# CBKNT_1CO_raw.txt  CBKNT_2PE_raw.txt  CBKNT_GAL_raw.txt  CBKNT_MRK_raw.txt
# CBKNT_1JN_raw.csv  CBKNT_2TH_raw.csv  CBKNT_HEB_raw.csv  CBKNT_PHM_raw.csv
# CBKNT_1JN_raw.txt  CBKNT_2TH_raw.txt  CBKNT_HEB_raw.txt  CBKNT_PHM_raw.txt
# CBKNT_1PE_raw.csv  CBKNT_2TI_raw.csv  CBKNT_JAS_raw.csv  CBKNT_PHP_raw.csv
# CBKNT_1PE_raw.txt  CBKNT_2TI_raw.txt  CBKNT_JAS_raw.txt  CBKNT_PHP_raw.txt
# CBKNT_1TH_raw.csv  CBKNT_3JN_raw.csv  CBKNT_JHN_raw.csv  CBKNT_REV_raw.csv
# CBKNT_1TH_raw.txt  CBKNT_3JN_raw.txt  CBKNT_JHN_raw.txt  CBKNT_REV_raw.txt
# CBKNT_1TI_raw.csv  CBKNT_ACT_raw.csv  CBKNT_JUD_raw.csv  CBKNT_ROM_raw.csv
# CBKNT_1TI_raw.txt  CBKNT_ACT_raw.txt  CBKNT_JUD_raw.txt  CBKNT_ROM_raw.txt
# CBKNT_2CO_raw.csv  CBKNT_COL_raw.csv  CBKNT_LUK_raw.csv  CBKNT_TIT_raw.csv
# CBKNT_2CO_raw.txt  CBKNT_COL_raw.txt  CBKNT_LUK_raw.txt  CBKNT_TIT_raw.txt
# CBKNT_2JN_raw.csv  CBKNT_EPH_raw.csv  CBKNT_MAT_raw.csv
# CBKNT_2JN_raw.txt  CBKNT_EPH_raw.txt  CBKNT_MAT_raw.txt
#
# /content/data/unzipped/segmented/by_sentence/Ilokano:
# RIPV_1CH_raw.csv  RIPV_3JN_raw.txt  RIPV_HOS_raw.csv  RIPV_MIC_raw.txt
# RIPV_1CH_raw.txt  RIPV_ACT_raw.csv  RIPV_HOS_raw.txt  RIPV_MRK_raw.csv
# RIPV_1CO_raw.csv  RIPV_ACT_raw.txt  RIPV_ISA_raw.csv  RIPV_MRK_raw.txt
# RIPV_1CO_raw.txt  RIPV_AMO_raw.csv  RIPV_ISA_raw.txt  RIPV_NAM_raw.csv
# RIPV_1JN_raw.csv  RIPV_AMO_raw.txt  RIPV_JAS_raw.csv  RIPV_NAM_raw.txt
# RIPV_1JN_raw.txt  RIPV_COL_raw.csv  RIPV_JAS_raw.txt  RIPV_NEH_raw.csv
# RIPV_1KI_raw.csv  RIPV_COL_raw.txt  RIPV_JDG_raw.csv  RIPV_NEH_raw.txt
# RIPV_1KI_raw.txt  RIPV_DAN_raw.csv  RIPV_JDG_raw.txt  RIPV_NUM_raw.csv
# RIPV_1PE_raw.csv  RIPV_DAN_raw.txt  RIPV_JER_raw.csv  RIPV_NUM_raw.txt
# RIPV_1PE_raw.txt  RIPV_DEU_raw.csv  RIPV_JER_raw.txt  RIPV_OBA_raw.csv
# RIPV_1SA_raw.csv  RIPV_DEU_raw.txt  RIPV_JHN_raw.csv  RIPV_OBA_raw.txt
# RIPV_1SA_raw.txt  RIPV_ECC_raw.csv  RIPV_JHN_raw.txt  RIPV_PHM_raw.csv
# RIPV_1TH_raw.csv  RIPV_ECC_raw.txt  RIPV_JOB_raw.csv  RIPV_PHM_raw.txt
# RIPV_1TH_raw.txt  RIPV_EPH_raw.csv  RIPV_JOB_raw.txt  RIPV_PHP_raw.csv
# RIPV_1TI_raw.csv  RIPV_EPH_raw.txt  RIPV_JOL_raw.csv  RIPV_PHP_raw.txt
# RIPV_1TI_raw.txt  RIPV_EST_raw.csv  RIPV_JOL_raw.txt  RIPV_PRO_raw.csv
# RIPV_2CH_raw.csv  RIPV_EST_raw.txt  RIPV_JON_raw.csv  RIPV_PRO_raw.txt
# RIPV_2CH_raw.txt  RIPV_EXO_raw.csv  RIPV_JON_raw.txt  RIPV_PSA_raw.csv
# RIPV_2CO_raw.csv  RIPV_EXO_raw.txt  RIPV_JOS_raw.csv  RIPV_PSA_raw.txt
# RIPV_2CO_raw.txt  RIPV_EZK_raw.csv  RIPV_JOS_raw.txt  RIPV_REV_raw.csv
# RIPV_2JN_raw.csv  RIPV_EZK_raw.txt  RIPV_JUD_raw.csv  RIPV_REV_raw.txt
# RIPV_2JN_raw.txt  RIPV_EZR_raw.csv  RIPV_JUD_raw.txt  RIPV_ROM_raw.csv
# RIPV_2KI_raw.csv  RIPV_EZR_raw.txt  RIPV_LAM_raw.csv  RIPV_ROM_raw.txt
# RIPV_2KI_raw.txt  RIPV_GAL_raw.csv  RIPV_LAM_raw.txt  RIPV_RUT_raw.csv
# RIPV_2PE_raw.csv  RIPV_GAL_raw.txt  RIPV_LEV_raw.csv  RIPV_RUT_raw.txt
# RIPV_2PE_raw.txt  RIPV_GEN_raw.csv  RIPV_LEV_raw.txt  RIPV_SNG_raw.csv
# RIPV_2SA_raw.csv  RIPV_GEN_raw.txt  RIPV_LUK_raw.csv  RIPV_SNG_raw.txt
# RIPV_2SA_raw.txt  RIPV_HAB_raw.csv  RIPV_LUK_raw.txt  RIPV_TIT_raw.csv
# RIPV_2TH_raw.csv  RIPV_HAB_raw.txt  RIPV_MAL_raw.csv  RIPV_TIT_raw.txt
# RIPV_2TH_raw.txt  RIPV_HAG_raw.csv  RIPV_MAL_raw.txt  RIPV_ZEC_raw.csv
# RIPV_2TI_raw.csv  RIPV_HAG_raw.txt  RIPV_MAT_raw.csv  RIPV_ZEC_raw.txt
# RIPV_2TI_raw.txt  RIPV_HEB_raw.csv  RIPV_MAT_raw.txt  RIPV_ZEP_raw.csv
# RIPV_3JN_raw.csv  RIPV_HEB_raw.txt  RIPV_MIC_raw.csv  RIPV_ZEP_raw.txt
#
# /content/data/unzipped/segmented/by_sentence/Isnag:
# ISDNT_1CO_raw.csv  ISDNT_2PE_raw.txt  ISDNT_GAL_raw.csv  ISDNT_MAT_raw.txt
# ISDNT_1CO_raw.txt  ISDNT_2TH_raw.csv  ISDNT_GAL_raw.txt  ISDNT_MRK_raw.csv
# ISDNT_1JN_raw.csv  ISDNT_2TH_raw.txt  ISDNT_GEN_raw.csv  ISDNT_MRK_raw.txt
# ISDNT_1JN_raw.txt  ISDNT_2TI_raw.csv  ISDNT_GEN_raw.txt  ISDNT_PHM_raw.csv
# ISDNT_1PE_raw.csv  ISDNT_2TI_raw.txt  ISDNT_HEB_raw.csv  ISDNT_PHM_raw.txt
# ISDNT_1PE_raw.txt  ISDNT_3JN_raw.csv  ISDNT_HEB_raw.txt  ISDNT_PHP_raw.csv
# ISDNT_1TH_raw.csv  ISDNT_3JN_raw.txt  ISDNT_JAS_raw.csv  ISDNT_PHP_raw.txt
# ISDNT_1TH_raw.txt  ISDNT_ACT_raw.csv  ISDNT_JAS_raw.txt  ISDNT_REV_raw.csv
# ISDNT_1TI_raw.csv  ISDNT_ACT_raw.txt  ISDNT_JHN_raw.csv  ISDNT_REV_raw.txt
# ISDNT_1TI_raw.txt  ISDNT_COL_raw.csv  ISDNT_JHN_raw.txt  ISDNT_ROM_raw.csv
# ISDNT_2CO_raw.csv  ISDNT_COL_raw.txt  ISDNT_JUD_raw.csv  ISDNT_ROM_raw.txt
# ISDNT_2CO_raw.txt  ISDNT_EPH_raw.csv  ISDNT_JUD_raw.txt  ISDNT_TIT_raw.csv
# ISDNT_2JN_raw.csv  ISDNT_EPH_raw.txt  ISDNT_LUK_raw.csv  ISDNT_TIT_raw.txt
# ISDNT_2JN_raw.txt  ISDNT_EXO_raw.csv  ISDNT_LUK_raw.txt
# ISDNT_2PE_raw.csv  ISDNT_EXO_raw.txt  ISDNT_MAT_raw.csv
#
# /content/data/unzipped/segmented/by_sentence/Ivatan:
# VTSP_1CO_raw.csv  VTSP_2PE_raw.txt  VTSP_HEB_raw.csv  VTSP_PHM_raw.txt
# VTSP_1CO_raw.txt  VTSP_2TH_raw.csv  VTSP_HEB_raw.txt  VTSP_PHP_raw.csv
# VTSP_1JN_raw.csv  VTSP_2TH_raw.txt  VTSP_JAS_raw.csv  VTSP_PHP_raw.txt
# VTSP_1JN_raw.txt  VTSP_2TI_raw.csv  VTSP_JAS_raw.txt  VTSP_PRO_raw.csv
# VTSP_1PE_raw.csv  VTSP_2TI_raw.txt  VTSP_JHN_raw.csv  VTSP_PRO_raw.txt
# VTSP_1PE_raw.txt  VTSP_3JN_raw.csv  VTSP_JHN_raw.txt  VTSP_PSA_raw.csv
# VTSP_1TH_raw.csv  VTSP_3JN_raw.txt  VTSP_JUD_raw.csv  VTSP_PSA_raw.txt
# VTSP_1TH_raw.txt  VTSP_ACT_raw.csv  VTSP_JUD_raw.txt  VTSP_REV_raw.csv
# VTSP_1TI_raw.csv  VTSP_ACT_raw.txt  VTSP_LUK_raw.csv  VTSP_REV_raw.txt
# VTSP_1TI_raw.txt  VTSP_COL_raw.csv  VTSP_LUK_raw.txt  VTSP_ROM_raw.csv
# VTSP_2CO_raw.csv  VTSP_COL_raw.txt  VTSP_MAT_raw.csv  VTSP_ROM_raw.txt
# VTSP_2CO_raw.txt  VTSP_EPH_raw.csv  VTSP_MAT_raw.txt  VTSP_TIT_raw.csv
# VTSP_2JN_raw.csv  VTSP_EPH_raw.txt  VTSP_MRK_raw.csv  VTSP_TIT_raw.txt
# VTSP_2JN_raw.txt  VTSP_GAL_raw.csv  VTSP_MRK_raw.txt
# VTSP_2PE_raw.csv  VTSP_GAL_raw.txt  VTSP_PHM_raw.csv
#
# /content/data/unzipped/segmented/by_sentence/Kalinga:
# kmk_1CO_raw.csv  kmk_2PE_raw.csv  kmk_GAL_raw.csv  kmk_MRK_raw.csv
# kmk_1CO_raw.txt  kmk_2PE_raw.txt  kmk_GAL_raw.txt  kmk_MRK_raw.txt
# kmk_1JN_raw.csv  kmk_2TH_raw.csv  kmk_HEB_raw.csv  kmk_PHM_raw.csv
# kmk_1JN_raw.txt  kmk_2TH_raw.txt  kmk_HEB_raw.txt  kmk_PHM_raw.txt
# kmk_1PE_raw.csv  kmk_2TI_raw.csv  kmk_JAS_raw.csv  kmk_PHP_raw.csv
# kmk_1PE_raw.txt  kmk_2TI_raw.txt  kmk_JAS_raw.txt  kmk_PHP_raw.txt
# kmk_1TH_raw.csv  kmk_3JN_raw.csv  kmk_JHN_raw.csv  kmk_REV_raw.csv
# kmk_1TH_raw.txt  kmk_3JN_raw.txt  kmk_JHN_raw.txt  kmk_REV_raw.txt
# kmk_1TI_raw.csv  kmk_ACT_raw.csv  kmk_JUD_raw.csv  kmk_ROM_raw.csv
# kmk_1TI_raw.txt  kmk_ACT_raw.txt  kmk_JUD_raw.txt  kmk_ROM_raw.txt
# kmk_2CO_raw.csv  kmk_COL_raw.csv  kmk_LUK_raw.csv  kmk_TIT_raw.csv
# kmk_2CO_raw.txt  kmk_COL_raw.txt  kmk_LUK_raw.txt  kmk_TIT_raw.txt
# kmk_2JN_raw.csv  kmk_EPH_raw.csv  kmk_MAT_raw.csv
# kmk_2JN_raw.txt  kmk_EPH_raw.txt  kmk_MAT_raw.txt
#
# /content/data/unzipped/segmented/by_sentence/Kankanaey:
# XNN_1CO_raw.csv  XNN_3JN_raw.txt  XNN_ISA_raw.csv  XNN_MIC_raw.txt
# XNN_1CO_raw.txt  XNN_ACT_raw.csv  XNN_ISA_raw.txt  XNN_MRK_raw.csv
# XNN_1JN_raw.csv  XNN_ACT_raw.txt  XNN_JAS_raw.csv  XNN_MRK_raw.txt
# XNN_1JN_raw.txt  XNN_AMO_raw.csv  XNN_JAS_raw.txt  XNN_NEH_raw.csv
# XNN_1KI_raw.csv  XNN_AMO_raw.txt  XNN_JDG_raw.csv  XNN_NEH_raw.txt
# XNN_1KI_raw.txt  XNN_BAR_raw.csv  XNN_JDG_raw.txt  XNN_NUM_raw.csv
# XNN_1PE_raw.csv  XNN_BAR_raw.txt  XNN_JDT_raw.csv  XNN_NUM_raw.txt
# XNN_1PE_raw.txt  XNN_COL_raw.csv  XNN_JDT_raw.txt  XNN_PHM_raw.csv
# XNN_1SA_raw.csv  XNN_COL_raw.txt  XNN_JER_raw.csv  XNN_PHM_raw.txt
# XNN_1SA_raw.txt  XNN_DAN_raw.csv  XNN_JER_raw.txt  XNN_PHP_raw.csv
# XNN_1TH_raw.csv  XNN_DAN_raw.txt  XNN_JHN_raw.csv  XNN_PHP_raw.txt
# XNN_1TH_raw.txt  XNN_DEU_raw.csv  XNN_JHN_raw.txt  XNN_PRO_raw.csv
# XNN_1TI_raw.csv  XNN_DEU_raw.txt  XNN_JOB_raw.csv  XNN_PRO_raw.txt
# XNN_1TI_raw.txt  XNN_ECC_raw.csv  XNN_JOB_raw.txt  XNN_PSA_raw.csv
# XNN_2CH_raw.csv  XNN_ECC_raw.txt  XNN_JOL_raw.csv  XNN_PSA_raw.txt
# XNN_2CH_raw.txt  XNN_EPH_raw.csv  XNN_JOL_raw.txt  XNN_REV_raw.csv
# XNN_2CO_raw.csv  XNN_EPH_raw.txt  XNN_JON_raw.csv  XNN_REV_raw.txt
# XNN_2CO_raw.txt  XNN_EXO_raw.csv  XNN_JON_raw.txt  XNN_ROM_raw.csv
# XNN_2JN_raw.csv  XNN_EXO_raw.txt  XNN_JOS_raw.csv  XNN_ROM_raw.txt
# XNN_2JN_raw.txt  XNN_EZK_raw.csv  XNN_JOS_raw.txt  XNN_RUT_raw.csv
# XNN_2KI_raw.csv  XNN_EZK_raw.txt  XNN_JUD_raw.csv  XNN_RUT_raw.txt
# XNN_2KI_raw.txt  XNN_GAL_raw.csv  XNN_JUD_raw.txt  XNN_SIR_raw.csv
# XNN_2PE_raw.csv  XNN_GAL_raw.txt  XNN_LEV_raw.csv  XNN_SIR_raw.txt
# XNN_2PE_raw.txt  XNN_GEN_raw.csv  XNN_LEV_raw.txt  XNN_TIT_raw.csv
# XNN_2SA_raw.csv  XNN_GEN_raw.txt  XNN_LUK_raw.csv  XNN_TIT_raw.txt
# XNN_2SA_raw.txt  XNN_HAB_raw.csv  XNN_LUK_raw.txt  XNN_WIS_raw.csv
# XNN_2TH_raw.csv  XNN_HAB_raw.txt  XNN_MAL_raw.csv  XNN_WIS_raw.txt
# XNN_2TH_raw.txt  XNN_HEB_raw.csv  XNN_MAL_raw.txt  XNN_ZEC_raw.csv
# XNN_2TI_raw.csv  XNN_HEB_raw.txt  XNN_MAT_raw.csv  XNN_ZEC_raw.txt
# XNN_2TI_raw.txt  XNN_HOS_raw.csv  XNN_MAT_raw.txt  XNN_ZEP_raw.csv
# XNN_3JN_raw.csv  XNN_HOS_raw.txt  XNN_MIC_raw.csv  XNN_ZEP_raw.txt
#
# /content/data/unzipped/segmented/by_sentence/Kapampangan:
# PmPV_1CH_raw.csv  PmPV_ACT_raw.txt  PmPV_JAS_raw.csv  PmPV_NEH_raw.txt
# PmPV_1CH_raw.txt  PmPV_AMO_raw.csv  PmPV_JAS_raw.txt  PmPV_NUM_raw.csv
# PmPV_1CO_raw.csv  PmPV_AMO_raw.txt  PmPV_JDG_raw.csv  PmPV_NUM_raw.txt
# PmPV_1CO_raw.txt  PmPV_BAR_raw.csv  PmPV_JDG_raw.txt  PmPV_OBA_raw.csv
# PmPV_1JN_raw.csv  PmPV_BAR_raw.txt  PmPV_JDT_raw.csv  PmPV_OBA_raw.txt
# PmPV_1JN_raw.txt  PmPV_BEL_raw.csv  PmPV_JDT_raw.txt  PmPV_PHM_raw.csv
# PmPV_1KI_raw.csv  PmPV_BEL_raw.txt  PmPV_JER_raw.csv  PmPV_PHM_raw.txt
# PmPV_1KI_raw.txt  PmPV_COL_raw.csv  PmPV_JER_raw.txt  PmPV_PHP_raw.csv
# PmPV_1MA_raw.csv  PmPV_COL_raw.txt  PmPV_JHN_raw.csv  PmPV_PHP_raw.txt
# PmPV_1MA_raw.txt  PmPV_DAN_raw.csv  PmPV_JHN_raw.txt  PmPV_PRO_raw.csv
# PmPV_1PE_raw.csv  PmPV_DAN_raw.txt  PmPV_JOB_raw.csv  PmPV_PRO_raw.txt
# PmPV_1PE_raw.txt  PmPV_DEU_raw.csv  PmPV_JOB_raw.txt  PmPV_PSA_raw.csv
# PmPV_1SA_raw.csv  PmPV_DEU_raw.txt  PmPV_JOL_raw.csv  PmPV_PSA_raw.txt
# PmPV_1SA_raw.txt  PmPV_ECC_raw.csv  PmPV_JOL_raw.txt  PmPV_REV_raw.csv
# PmPV_1TH_raw.csv  PmPV_ECC_raw.txt  PmPV_JON_raw.csv  PmPV_REV_raw.txt
# PmPV_1TH_raw.txt  PmPV_EPH_raw.csv  PmPV_JON_raw.txt  PmPV_ROM_raw.csv
# PmPV_1TI_raw.csv  PmPV_EPH_raw.txt  PmPV_JOS_raw.csv  PmPV_ROM_raw.txt
# PmPV_1TI_raw.txt  PmPV_EST_raw.csv  PmPV_JOS_raw.txt  PmPV_RUT_raw.csv
# PmPV_2CH_raw.csv  PmPV_EST_raw.txt  PmPV_JUD_raw.csv  PmPV_RUT_raw.txt
# PmPV_2CH_raw.txt  PmPV_EXO_raw.csv  PmPV_JUD_raw.txt  PmPV_S3Y_raw.csv
# PmPV_2CO_raw.csv  PmPV_EXO_raw.txt  PmPV_LAM_raw.csv  PmPV_S3Y_raw.txt
# PmPV_2CO_raw.txt  PmPV_EZK_raw.csv  PmPV_LAM_raw.txt  PmPV_SIR_raw.csv
# PmPV_2JN_raw.csv  PmPV_EZK_raw.txt  PmPV_LEV_raw.csv  PmPV_SIR_raw.txt
# PmPV_2JN_raw.txt  PmPV_EZR_raw.csv  PmPV_LEV_raw.txt  PmPV_SNG_raw.csv
# PmPV_2KI_raw.csv  PmPV_EZR_raw.txt  PmPV_LJE_raw.csv  PmPV_SNG_raw.txt
# PmPV_2KI_raw.txt  PmPV_GAL_raw.csv  PmPV_LJE_raw.txt  PmPV_SUS_raw.csv
# PmPV_2MA_raw.csv  PmPV_GAL_raw.txt  PmPV_LUK_raw.csv  PmPV_SUS_raw.txt
# PmPV_2MA_raw.txt  PmPV_GEN_raw.csv  PmPV_LUK_raw.txt  PmPV_TIT_raw.csv
# PmPV_2PE_raw.csv  PmPV_GEN_raw.txt  PmPV_MAL_raw.csv  PmPV_TIT_raw.txt
# PmPV_2PE_raw.txt  PmPV_HAB_raw.csv  PmPV_MAL_raw.txt  PmPV_TOB_raw.csv
# PmPV_2SA_raw.csv  PmPV_HAB_raw.txt  PmPV_MAT_raw.csv  PmPV_TOB_raw.txt
# PmPV_2SA_raw.txt  PmPV_HAG_raw.csv  PmPV_MAT_raw.txt  PmPV_WIS_raw.csv
# PmPV_2TH_raw.csv  PmPV_HAG_raw.txt  PmPV_MIC_raw.csv  PmPV_WIS_raw.txt
# PmPV_2TH_raw.txt  PmPV_HEB_raw.csv  PmPV_MIC_raw.txt  PmPV_ZEC_raw.csv
# PmPV_2TI_raw.csv  PmPV_HEB_raw.txt  PmPV_MRK_raw.csv  PmPV_ZEC_raw.txt
# PmPV_2TI_raw.txt  PmPV_HOS_raw.csv  PmPV_MRK_raw.txt  PmPV_ZEP_raw.csv
# PmPV_3JN_raw.csv  PmPV_HOS_raw.txt  PmPV_NAM_raw.csv  PmPV_ZEP_raw.txt
# PmPV_3JN_raw.txt  PmPV_ISA_raw.csv  PmPV_NAM_raw.txt
# PmPV_ACT_raw.csv  PmPV_ISA_raw.txt  PmPV_NEH_raw.csv
#
# /content/data/unzipped/segmented/by_sentence/Pangasinense:
# PNPV_1CH_raw.csv  PNPV_ACT_raw.txt  PNPV_JAS_raw.csv  PNPV_NEH_raw.txt
# PNPV_1CH_raw.txt  PNPV_AMO_raw.csv  PNPV_JAS_raw.txt  PNPV_NUM_raw.csv
# PNPV_1CO_raw.csv  PNPV_AMO_raw.txt  PNPV_JDG_raw.csv  PNPV_NUM_raw.txt
# PNPV_1CO_raw.txt  PNPV_BAR_raw.csv  PNPV_JDG_raw.txt  PNPV_OBA_raw.csv
# PNPV_1JN_raw.csv  PNPV_BAR_raw.txt  PNPV_JDT_raw.csv  PNPV_OBA_raw.txt
# PNPV_1JN_raw.txt  PNPV_BEL_raw.csv  PNPV_JDT_raw.txt  PNPV_PHM_raw.csv
# PNPV_1KI_raw.csv  PNPV_BEL_raw.txt  PNPV_JER_raw.csv  PNPV_PHM_raw.txt
# PNPV_1KI_raw.txt  PNPV_COL_raw.csv  PNPV_JER_raw.txt  PNPV_PHP_raw.csv
# PNPV_1MA_raw.csv  PNPV_COL_raw.txt  PNPV_JHN_raw.csv  PNPV_PHP_raw.txt
# PNPV_1MA_raw.txt  PNPV_DAN_raw.csv  PNPV_JHN_raw.txt  PNPV_PRO_raw.csv
# PNPV_1PE_raw.csv  PNPV_DAN_raw.txt  PNPV_JOB_raw.csv  PNPV_PRO_raw.txt
# PNPV_1PE_raw.txt  PNPV_DEU_raw.csv  PNPV_JOB_raw.txt  PNPV_PSA_raw.csv
# PNPV_1SA_raw.csv  PNPV_DEU_raw.txt  PNPV_JOL_raw.csv  PNPV_PSA_raw.txt
# PNPV_1SA_raw.txt  PNPV_ECC_raw.csv  PNPV_JOL_raw.txt  PNPV_REV_raw.csv
# PNPV_1TH_raw.csv  PNPV_ECC_raw.txt  PNPV_JON_raw.csv  PNPV_REV_raw.txt
# PNPV_1TH_raw.txt  PNPV_EPH_raw.csv  PNPV_JON_raw.txt  PNPV_ROM_raw.csv
# PNPV_1TI_raw.csv  PNPV_EPH_raw.txt  PNPV_JOS_raw.csv  PNPV_ROM_raw.txt
# PNPV_1TI_raw.txt  PNPV_EST_raw.csv  PNPV_JOS_raw.txt  PNPV_RUT_raw.csv
# PNPV_2CH_raw.csv  PNPV_EST_raw.txt  PNPV_JUD_raw.csv  PNPV_RUT_raw.txt
# PNPV_2CH_raw.txt  PNPV_EXO_raw.csv  PNPV_JUD_raw.txt  PNPV_S3Y_raw.csv
# PNPV_2CO_raw.csv  PNPV_EXO_raw.txt  PNPV_LAM_raw.csv  PNPV_S3Y_raw.txt
# PNPV_2CO_raw.txt  PNPV_EZK_raw.csv  PNPV_LAM_raw.txt  PNPV_SIR_raw.csv
# PNPV_2JN_raw.csv  PNPV_EZK_raw.txt  PNPV_LEV_raw.csv  PNPV_SIR_raw.txt
# PNPV_2JN_raw.txt  PNPV_EZR_raw.csv  PNPV_LEV_raw.txt  PNPV_SNG_raw.csv
# PNPV_2KI_raw.csv  PNPV_EZR_raw.txt  PNPV_LJE_raw.csv  PNPV_SNG_raw.txt
# PNPV_2KI_raw.txt  PNPV_GAL_raw.csv  PNPV_LJE_raw.txt  PNPV_SUS_raw.csv
# PNPV_2MA_raw.csv  PNPV_GAL_raw.txt  PNPV_LUK_raw.csv  PNPV_SUS_raw.txt
# PNPV_2MA_raw.txt  PNPV_GEN_raw.csv  PNPV_LUK_raw.txt  PNPV_TIT_raw.csv
# PNPV_2PE_raw.csv  PNPV_GEN_raw.txt  PNPV_MAL_raw.csv  PNPV_TIT_raw.txt
# PNPV_2PE_raw.txt  PNPV_HAB_raw.csv  PNPV_MAL_raw.txt  PNPV_TOB_raw.csv
# PNPV_2SA_raw.csv  PNPV_HAB_raw.txt  PNPV_MAT_raw.csv  PNPV_TOB_raw.txt
# PNPV_2SA_raw.txt  PNPV_HAG_raw.csv  PNPV_MAT_raw.txt  PNPV_WIS_raw.csv
# PNPV_2TH_raw.csv  PNPV_HAG_raw.txt  PNPV_MIC_raw.csv  PNPV_WIS_raw.txt
# PNPV_2TH_raw.txt  PNPV_HEB_raw.csv  PNPV_MIC_raw.txt  PNPV_ZEC_raw.csv
# PNPV_2TI_raw.csv  PNPV_HEB_raw.txt  PNPV_MRK_raw.csv  PNPV_ZEC_raw.txt
# PNPV_2TI_raw.txt  PNPV_HOS_raw.csv  PNPV_MRK_raw.txt  PNPV_ZEP_raw.csv
# PNPV_3JN_raw.csv  PNPV_HOS_raw.txt  PNPV_NAM_raw.csv  PNPV_ZEP_raw.txt
# PNPV_3JN_raw.txt  PNPV_ISA_raw.csv  PNPV_NAM_raw.txt
# PNPV_ACT_raw.csv  PNPV_ISA_raw.txt  PNPV_NEH_raw.csv
#
# /content/data/unzipped/segmented/by_sentence/Sambal:
# XSB_1CO_raw.csv  XSB_2PE_raw.csv  XSB_GAL_raw.csv  XSB_MRK_raw.csv
# XSB_1CO_raw.txt  XSB_2PE_raw.txt  XSB_GAL_raw.txt  XSB_MRK_raw.txt
# XSB_1JN_raw.csv  XSB_2TH_raw.csv  XSB_HEB_raw.csv  XSB_PHM_raw.csv
# XSB_1JN_raw.txt  XSB_2TH_raw.txt  XSB_HEB_raw.txt  XSB_PHM_raw.txt
# XSB_1PE_raw.csv  XSB_2TI_raw.csv  XSB_JAS_raw.csv  XSB_PHP_raw.csv
# XSB_1PE_raw.txt  XSB_2TI_raw.txt  XSB_JAS_raw.txt  XSB_PHP_raw.txt
# XSB_1TH_raw.csv  XSB_3JN_raw.csv  XSB_JHN_raw.csv  XSB_REV_raw.csv
# XSB_1TH_raw.txt  XSB_3JN_raw.txt  XSB_JHN_raw.txt  XSB_REV_raw.txt
# XSB_1TI_raw.csv  XSB_ACT_raw.csv  XSB_JUD_raw.csv  XSB_ROM_raw.csv
# XSB_1TI_raw.txt  XSB_ACT_raw.txt  XSB_JUD_raw.txt  XSB_ROM_raw.txt
# XSB_2CO_raw.csv  XSB_COL_raw.csv  XSB_LUK_raw.csv  XSB_TIT_raw.csv
# XSB_2CO_raw.txt  XSB_COL_raw.txt  XSB_LUK_raw.txt  XSB_TIT_raw.txt
# XSB_2JN_raw.csv  XSB_EPH_raw.csv  XSB_MAT_raw.csv
# XSB_2JN_raw.txt  XSB_EPH_raw.txt  XSB_MAT_raw.txt
#
# /content/data/unzipped/segmented/by_sentence/Spanish:
# RVR95_1CH_raw.csv  RVR95_3JN_raw.txt  RVR95_HOS_raw.csv  RVR95_MIC_raw.txt
# RVR95_1CH_raw.txt  RVR95_ACT_raw.csv  RVR95_HOS_raw.txt  RVR95_MRK_raw.csv
# RVR95_1CO_raw.csv  RVR95_ACT_raw.txt  RVR95_ISA_raw.csv  RVR95_MRK_raw.txt
# RVR95_1CO_raw.txt  RVR95_AMO_raw.csv  RVR95_ISA_raw.txt  RVR95_NAM_raw.csv
# RVR95_1JN_raw.csv  RVR95_AMO_raw.txt  RVR95_JAS_raw.csv  RVR95_NAM_raw.txt
# RVR95_1JN_raw.txt  RVR95_COL_raw.csv  RVR95_JAS_raw.txt  RVR95_NEH_raw.csv
# RVR95_1KI_raw.csv  RVR95_COL_raw.txt  RVR95_JDG_raw.csv  RVR95_NEH_raw.txt
# RVR95_1KI_raw.txt  RVR95_DAN_raw.csv  RVR95_JDG_raw.txt  RVR95_NUM_raw.csv
# RVR95_1PE_raw.csv  RVR95_DAN_raw.txt  RVR95_JER_raw.csv  RVR95_NUM_raw.txt
# RVR95_1PE_raw.txt  RVR95_DEU_raw.csv  RVR95_JER_raw.txt  RVR95_OBA_raw.csv
# RVR95_1SA_raw.csv  RVR95_DEU_raw.txt  RVR95_JHN_raw.csv  RVR95_OBA_raw.txt
# RVR95_1SA_raw.txt  RVR95_ECC_raw.csv  RVR95_JHN_raw.txt  RVR95_PHM_raw.csv
# RVR95_1TH_raw.csv  RVR95_ECC_raw.txt  RVR95_JOB_raw.csv  RVR95_PHM_raw.txt
# RVR95_1TH_raw.txt  RVR95_EPH_raw.csv  RVR95_JOB_raw.txt  RVR95_PHP_raw.csv
# RVR95_1TI_raw.csv  RVR95_EPH_raw.txt  RVR95_JOL_raw.csv  RVR95_PHP_raw.txt
# RVR95_1TI_raw.txt  RVR95_EST_raw.csv  RVR95_JOL_raw.txt  RVR95_PRO_raw.csv
# RVR95_2CH_raw.csv  RVR95_EST_raw.txt  RVR95_JON_raw.csv  RVR95_PRO_raw.txt
# RVR95_2CH_raw.txt  RVR95_EXO_raw.csv  RVR95_JON_raw.txt  RVR95_PSA_raw.csv
# RVR95_2CO_raw.csv  RVR95_EXO_raw.txt  RVR95_JOS_raw.csv  RVR95_PSA_raw.txt
# RVR95_2CO_raw.txt  RVR95_EZK_raw.csv  RVR95_JOS_raw.txt  RVR95_REV_raw.csv
# RVR95_2JN_raw.csv  RVR95_EZK_raw.txt  RVR95_JUD_raw.csv  RVR95_REV_raw.txt
# RVR95_2JN_raw.txt  RVR95_EZR_raw.csv  RVR95_JUD_raw.txt  RVR95_ROM_raw.csv
# RVR95_2KI_raw.csv  RVR95_EZR_raw.txt  RVR95_LAM_raw.csv  RVR95_ROM_raw.txt
# RVR95_2KI_raw.txt  RVR95_GAL_raw.csv  RVR95_LAM_raw.txt  RVR95_RUT_raw.csv
# RVR95_2PE_raw.csv  RVR95_GAL_raw.txt  RVR95_LEV_raw.csv  RVR95_RUT_raw.txt
# RVR95_2PE_raw.txt  RVR95_GEN_raw.csv  RVR95_LEV_raw.txt  RVR95_SNG_raw.csv
# RVR95_2SA_raw.csv  RVR95_GEN_raw.txt  RVR95_LUK_raw.csv  RVR95_SNG_raw.txt
# RVR95_2SA_raw.txt  RVR95_HAB_raw.csv  RVR95_LUK_raw.txt  RVR95_TIT_raw.csv
# RVR95_2TH_raw.csv  RVR95_HAB_raw.txt  RVR95_MAL_raw.csv  RVR95_TIT_raw.txt
# RVR95_2TH_raw.txt  RVR95_HAG_raw.csv  RVR95_MAL_raw.txt  RVR95_ZEC_raw.csv
# RVR95_2TI_raw.csv  RVR95_HAG_raw.txt  RVR95_MAT_raw.csv  RVR95_ZEC_raw.txt
# RVR95_2TI_raw.txt  RVR95_HEB_raw.csv  RVR95_MAT_raw.txt  RVR95_ZEP_raw.csv
# RVR95_3JN_raw.csv  RVR95_HEB_raw.txt  RVR95_MIC_raw.csv  RVR95_ZEP_raw.txt
#
# /content/data/unzipped/segmented/by_sentence/Tagalog:
# MBB05_1CH_raw.csv  MBB05_ACT_raw.txt  MBB05_JAS_raw.csv  MBB05_NEH_raw.txt
# MBB05_1CH_raw.txt  MBB05_AMO_raw.csv  MBB05_JAS_raw.txt  MBB05_NUM_raw.csv
# MBB05_1CO_raw.csv  MBB05_AMO_raw.txt  MBB05_JDG_raw.csv  MBB05_NUM_raw.txt
# MBB05_1CO_raw.txt  MBB05_BAR_raw.csv  MBB05_JDG_raw.txt  MBB05_OBA_raw.csv
# MBB05_1JN_raw.csv  MBB05_BAR_raw.txt  MBB05_JDT_raw.csv  MBB05_OBA_raw.txt
# MBB05_1JN_raw.txt  MBB05_BEL_raw.csv  MBB05_JDT_raw.txt  MBB05_PHM_raw.csv
# MBB05_1KI_raw.csv  MBB05_BEL_raw.txt  MBB05_JER_raw.csv  MBB05_PHM_raw.txt
# MBB05_1KI_raw.txt  MBB05_COL_raw.csv  MBB05_JER_raw.txt  MBB05_PHP_raw.csv
# MBB05_1MA_raw.csv  MBB05_COL_raw.txt  MBB05_JHN_raw.csv  MBB05_PHP_raw.txt
# MBB05_1MA_raw.txt  MBB05_DAN_raw.csv  MBB05_JHN_raw.txt  MBB05_PRO_raw.csv
# MBB05_1PE_raw.csv  MBB05_DAN_raw.txt  MBB05_JOB_raw.csv  MBB05_PRO_raw.txt
# MBB05_1PE_raw.txt  MBB05_DEU_raw.csv  MBB05_JOB_raw.txt  MBB05_PSA_raw.csv
# MBB05_1SA_raw.csv  MBB05_DEU_raw.txt  MBB05_JOL_raw.csv  MBB05_PSA_raw.txt
# MBB05_1SA_raw.txt  MBB05_ECC_raw.csv  MBB05_JOL_raw.txt  MBB05_REV_raw.csv
# MBB05_1TH_raw.csv  MBB05_ECC_raw.txt  MBB05_JON_raw.csv  MBB05_REV_raw.txt
# MBB05_1TH_raw.txt  MBB05_EPH_raw.csv  MBB05_JON_raw.txt  MBB05_ROM_raw.csv
# MBB05_1TI_raw.csv  MBB05_EPH_raw.txt  MBB05_JOS_raw.csv  MBB05_ROM_raw.txt
# MBB05_1TI_raw.txt  MBB05_EST_raw.csv  MBB05_JOS_raw.txt  MBB05_RUT_raw.csv
# MBB05_2CH_raw.csv  MBB05_EST_raw.txt  MBB05_JUD_raw.csv  MBB05_RUT_raw.txt
# MBB05_2CH_raw.txt  MBB05_EXO_raw.csv  MBB05_JUD_raw.txt  MBB05_S3Y_raw.csv
# MBB05_2CO_raw.csv  MBB05_EXO_raw.txt  MBB05_LAM_raw.csv  MBB05_S3Y_raw.txt
# MBB05_2CO_raw.txt  MBB05_EZK_raw.csv  MBB05_LAM_raw.txt  MBB05_SIR_raw.csv
# MBB05_2JN_raw.csv  MBB05_EZK_raw.txt  MBB05_LEV_raw.csv  MBB05_SIR_raw.txt
# MBB05_2JN_raw.txt  MBB05_EZR_raw.csv  MBB05_LEV_raw.txt  MBB05_SNG_raw.csv
# MBB05_2KI_raw.csv  MBB05_EZR_raw.txt  MBB05_LJE_raw.csv  MBB05_SNG_raw.txt
# MBB05_2KI_raw.txt  MBB05_GAL_raw.csv  MBB05_LJE_raw.txt  MBB05_SUS_raw.csv
# MBB05_2MA_raw.csv  MBB05_GAL_raw.txt  MBB05_LUK_raw.csv  MBB05_SUS_raw.txt
# MBB05_2MA_raw.txt  MBB05_GEN_raw.csv  MBB05_LUK_raw.txt  MBB05_TIT_raw.csv
# MBB05_2PE_raw.csv  MBB05_GEN_raw.txt  MBB05_MAL_raw.csv  MBB05_TIT_raw.txt
# MBB05_2PE_raw.txt  MBB05_HAB_raw.csv  MBB05_MAL_raw.txt  MBB05_TOB_raw.csv
# MBB05_2SA_raw.csv  MBB05_HAB_raw.txt  MBB05_MAT_raw.csv  MBB05_TOB_raw.txt
# MBB05_2SA_raw.txt  MBB05_HAG_raw.csv  MBB05_MAT_raw.txt  MBB05_WIS_raw.csv
# MBB05_2TH_raw.csv  MBB05_HAG_raw.txt  MBB05_MIC_raw.csv  MBB05_WIS_raw.txt
# MBB05_2TH_raw.txt  MBB05_HEB_raw.csv  MBB05_MIC_raw.txt  MBB05_ZEC_raw.csv
# MBB05_2TI_raw.csv  MBB05_HEB_raw.txt  MBB05_MRK_raw.csv  MBB05_ZEC_raw.txt
# MBB05_2TI_raw.txt  MBB05_HOS_raw.csv  MBB05_MRK_raw.txt  MBB05_ZEP_raw.csv
# MBB05_3JN_raw.csv  MBB05_HOS_raw.txt  MBB05_NAM_raw.csv  MBB05_ZEP_raw.txt
# MBB05_3JN_raw.txt  MBB05_ISA_raw.csv  MBB05_NAM_raw.txt
# MBB05_ACT_raw.csv  MBB05_ISA_raw.txt  MBB05_NEH_raw.csv
#
# /content/data/unzipped/segmented/by_sentence/Tausug:
# TSG_1CO_raw.csv  TSG_2PE_raw.csv  TSG_GAL_raw.csv  TSG_MRK_raw.csv
# TSG_1CO_raw.txt  TSG_2PE_raw.txt  TSG_GAL_raw.txt  TSG_MRK_raw.txt
# TSG_1JN_raw.csv  TSG_2TH_raw.csv  TSG_HEB_raw.csv  TSG_PHM_raw.csv
# TSG_1JN_raw.txt  TSG_2TH_raw.txt  TSG_HEB_raw.txt  TSG_PHM_raw.txt
# TSG_1PE_raw.csv  TSG_2TI_raw.csv  TSG_JAS_raw.csv  TSG_PHP_raw.csv
# TSG_1PE_raw.txt  TSG_2TI_raw.txt  TSG_JAS_raw.txt  TSG_PHP_raw.txt
# TSG_1TH_raw.csv  TSG_3JN_raw.csv  TSG_JHN_raw.csv  TSG_REV_raw.csv
# TSG_1TH_raw.txt  TSG_3JN_raw.txt  TSG_JHN_raw.txt  TSG_REV_raw.txt
# TSG_1TI_raw.csv  TSG_ACT_raw.csv  TSG_JUD_raw.csv  TSG_ROM_raw.csv
# TSG_1TI_raw.txt  TSG_ACT_raw.txt  TSG_JUD_raw.txt  TSG_ROM_raw.txt
# TSG_2CO_raw.csv  TSG_COL_raw.csv  TSG_LUK_raw.csv  TSG_TIT_raw.csv
# TSG_2CO_raw.txt  TSG_COL_raw.txt  TSG_LUK_raw.txt  TSG_TIT_raw.txt
# TSG_2JN_raw.csv  TSG_EPH_raw.csv  TSG_MAT_raw.csv
# TSG_2JN_raw.txt  TSG_EPH_raw.txt  TSG_MAT_raw.txt
#
# /content/data/unzipped/segmented/by_sentence/Yakan:
# YAKV_1CO_raw.csv  YAKV_2PE_raw.txt  YAKV_GEN_raw.csv  YAKV_MAT_raw.txt
# YAKV_1CO_raw.txt  YAKV_2TH_raw.csv  YAKV_GEN_raw.txt  YAKV_MRK_raw.csv
# YAKV_1JN_raw.csv  YAKV_2TH_raw.txt  YAKV_HEB_raw.csv  YAKV_MRK_raw.txt
# YAKV_1JN_raw.txt  YAKV_2TI_raw.csv  YAKV_HEB_raw.txt  YAKV_PHM_raw.csv
# YAKV_1PE_raw.csv  YAKV_2TI_raw.txt  YAKV_JAS_raw.csv  YAKV_PHM_raw.txt
# YAKV_1PE_raw.txt  YAKV_3JN_raw.csv  YAKV_JAS_raw.txt  YAKV_PHP_raw.csv
# YAKV_1TH_raw.csv  YAKV_3JN_raw.txt  YAKV_JHN_raw.csv  YAKV_PHP_raw.txt
# YAKV_1TH_raw.txt  YAKV_ACT_raw.csv  YAKV_JHN_raw.txt  YAKV_REV_raw.csv
# YAKV_1TI_raw.csv  YAKV_ACT_raw.txt  YAKV_JON_raw.csv  YAKV_REV_raw.txt
# YAKV_1TI_raw.txt  YAKV_COL_raw.csv  YAKV_JON_raw.txt  YAKV_ROM_raw.csv
# YAKV_2CO_raw.csv  YAKV_COL_raw.txt  YAKV_JUD_raw.csv  YAKV_ROM_raw.txt
# YAKV_2CO_raw.txt  YAKV_EPH_raw.csv  YAKV_JUD_raw.txt  YAKV_RUT_raw.csv
# YAKV_2JN_raw.csv  YAKV_EPH_raw.txt  YAKV_LUK_raw.csv  YAKV_RUT_raw.txt
# YAKV_2JN_raw.txt  YAKV_GAL_raw.csv  YAKV_LUK_raw.txt  YAKV_TIT_raw.csv
# YAKV_2PE_raw.csv  YAKV_GAL_raw.txt  YAKV_MAT_raw.csv  YAKV_TIT_raw.txt
#
# /content/data/unzipped/segmented/by_sentence/Yami:
# SNT_1CO_raw.csv  SNT_2PE_raw.csv  SNT_GAL_raw.csv  SNT_MRK_raw.csv
# SNT_1CO_raw.txt  SNT_2PE_raw.txt  SNT_GAL_raw.txt  SNT_MRK_raw.txt
# SNT_1JN_raw.csv  SNT_2TH_raw.csv  SNT_HEB_raw.csv  SNT_PHM_raw.csv
# SNT_1JN_raw.txt  SNT_2TH_raw.txt  SNT_HEB_raw.txt  SNT_PHM_raw.txt
# SNT_1PE_raw.csv  SNT_2TI_raw.csv  SNT_JAS_raw.csv  SNT_PHP_raw.csv
# SNT_1PE_raw.txt  SNT_2TI_raw.txt  SNT_JAS_raw.txt  SNT_PHP_raw.txt
# SNT_1TH_raw.csv  SNT_3JN_raw.csv  SNT_JHN_raw.csv  SNT_REV_raw.csv
# SNT_1TH_raw.txt  SNT_3JN_raw.txt  SNT_JHN_raw.txt  SNT_REV_raw.txt
# SNT_1TI_raw.csv  SNT_ACT_raw.csv  SNT_JUD_raw.csv  SNT_ROM_raw.csv
# SNT_1TI_raw.txt  SNT_ACT_raw.txt  SNT_JUD_raw.txt  SNT_ROM_raw.txt
# SNT_2CO_raw.csv  SNT_COL_raw.csv  SNT_LUK_raw.csv  SNT_TIT_raw.csv
# SNT_2CO_raw.txt  SNT_COL_raw.txt  SNT_LUK_raw.txt  SNT_TIT_raw.txt
# SNT_2JN_raw.csv  SNT_EPH_raw.csv  SNT_MAT_raw.csv
# SNT_2JN_raw.txt  SNT_EPH_raw.txt  SNT_MAT_raw.txt
#
# /content/data/unzipped/segmented/by_verse:
# Bikolano  Chavacano  Isnag   Kalinga	Kapampangan   Sambal   Tagalog	Yakan
# Cebuano   Ilokano    Ivatan  Kankanaey	Pangasinense  Spanish  Tausug	Yami
#
# /content/data/unzipped/segmented/by_verse/Bikolano:
# MBBBIK92_1CH_raw.csv  MBBBIK92_ECC_raw.csv  MBBBIK92_LUK_raw.csv
# MBBBIK92_1CH_raw.txt  MBBBIK92_ECC_raw.txt  MBBBIK92_LUK_raw.txt
# MBBBIK92_1CO_raw.csv  MBBBIK92_EPH_raw.csv  MBBBIK92_MAL_raw.csv
# MBBBIK92_1CO_raw.txt  MBBBIK92_EPH_raw.txt  MBBBIK92_MAL_raw.txt
# MBBBIK92_1JN_raw.csv  MBBBIK92_EST_raw.csv  MBBBIK92_MAT_raw.csv
# MBBBIK92_1JN_raw.txt  MBBBIK92_EST_raw.txt  MBBBIK92_MAT_raw.txt
# MBBBIK92_1KI_raw.csv  MBBBIK92_EXO_raw.csv  MBBBIK92_MIC_raw.csv
# MBBBIK92_1KI_raw.txt  MBBBIK92_EXO_raw.txt  MBBBIK92_MIC_raw.txt
# MBBBIK92_1MA_raw.csv  MBBBIK92_EZK_raw.csv  MBBBIK92_MRK_raw.csv
# MBBBIK92_1MA_raw.txt  MBBBIK92_EZK_raw.txt  MBBBIK92_MRK_raw.txt
# MBBBIK92_1PE_raw.csv  MBBBIK92_EZR_raw.csv  MBBBIK92_NAM_raw.csv
# MBBBIK92_1PE_raw.txt  MBBBIK92_EZR_raw.txt  MBBBIK92_NAM_raw.txt
# MBBBIK92_1SA_raw.csv  MBBBIK92_GAL_raw.csv  MBBBIK92_NEH_raw.csv
# MBBBIK92_1SA_raw.txt  MBBBIK92_GAL_raw.txt  MBBBIK92_NEH_raw.txt
# MBBBIK92_1TH_raw.csv  MBBBIK92_GEN_raw.csv  MBBBIK92_NUM_raw.csv
# MBBBIK92_1TH_raw.txt  MBBBIK92_GEN_raw.txt  MBBBIK92_NUM_raw.txt
# MBBBIK92_1TI_raw.csv  MBBBIK92_HAB_raw.csv  MBBBIK92_OBA_raw.csv
# MBBBIK92_1TI_raw.txt  MBBBIK92_HAB_raw.txt  MBBBIK92_OBA_raw.txt
# MBBBIK92_2CH_raw.csv  MBBBIK92_HAG_raw.csv  MBBBIK92_PHM_raw.csv
# MBBBIK92_2CH_raw.txt  MBBBIK92_HAG_raw.txt  MBBBIK92_PHM_raw.txt
# MBBBIK92_2CO_raw.csv  MBBBIK92_HEB_raw.csv  MBBBIK92_PHP_raw.csv
# MBBBIK92_2CO_raw.txt  MBBBIK92_HEB_raw.txt  MBBBIK92_PHP_raw.txt
# MBBBIK92_2JN_raw.csv  MBBBIK92_HOS_raw.csv  MBBBIK92_PRO_raw.csv
# MBBBIK92_2JN_raw.txt  MBBBIK92_HOS_raw.txt  MBBBIK92_PRO_raw.txt
# MBBBIK92_2KI_raw.csv  MBBBIK92_ISA_raw.csv  MBBBIK92_PSA_raw.csv
# MBBBIK92_2KI_raw.txt  MBBBIK92_ISA_raw.txt  MBBBIK92_PSA_raw.txt
# MBBBIK92_2MA_raw.csv  MBBBIK92_JAS_raw.csv  MBBBIK92_REV_raw.csv
# MBBBIK92_2MA_raw.txt  MBBBIK92_JAS_raw.txt  MBBBIK92_REV_raw.txt
# MBBBIK92_2PE_raw.csv  MBBBIK92_JDG_raw.csv  MBBBIK92_ROM_raw.csv
# MBBBIK92_2PE_raw.txt  MBBBIK92_JDG_raw.txt  MBBBIK92_ROM_raw.txt
# MBBBIK92_2SA_raw.csv  MBBBIK92_JDT_raw.csv  MBBBIK92_RUT_raw.csv
# MBBBIK92_2SA_raw.txt  MBBBIK92_JDT_raw.txt  MBBBIK92_RUT_raw.txt
# MBBBIK92_2TH_raw.csv  MBBBIK92_JER_raw.csv  MBBBIK92_S3Y_raw.csv
# MBBBIK92_2TH_raw.txt  MBBBIK92_JER_raw.txt  MBBBIK92_S3Y_raw.txt
# MBBBIK92_2TI_raw.csv  MBBBIK92_JHN_raw.csv  MBBBIK92_SIR_raw.csv
# MBBBIK92_2TI_raw.txt  MBBBIK92_JHN_raw.txt  MBBBIK92_SIR_raw.txt
# MBBBIK92_3JN_raw.csv  MBBBIK92_JOB_raw.csv  MBBBIK92_SNG_raw.csv
# MBBBIK92_3JN_raw.txt  MBBBIK92_JOB_raw.txt  MBBBIK92_SNG_raw.txt
# MBBBIK92_ACT_raw.csv  MBBBIK92_JOL_raw.csv  MBBBIK92_SUS_raw.csv
# MBBBIK92_ACT_raw.txt  MBBBIK92_JOL_raw.txt  MBBBIK92_SUS_raw.txt
# MBBBIK92_AMO_raw.csv  MBBBIK92_JON_raw.csv  MBBBIK92_TIT_raw.csv
# MBBBIK92_AMO_raw.txt  MBBBIK92_JON_raw.txt  MBBBIK92_TIT_raw.txt
# MBBBIK92_BAR_raw.csv  MBBBIK92_JOS_raw.csv  MBBBIK92_TOB_raw.csv
# MBBBIK92_BAR_raw.txt  MBBBIK92_JOS_raw.txt  MBBBIK92_TOB_raw.txt
# MBBBIK92_BEL_raw.csv  MBBBIK92_JUD_raw.csv  MBBBIK92_WIS_raw.csv
# MBBBIK92_BEL_raw.txt  MBBBIK92_JUD_raw.txt  MBBBIK92_WIS_raw.txt
# MBBBIK92_COL_raw.csv  MBBBIK92_LAM_raw.csv  MBBBIK92_ZEC_raw.csv
# MBBBIK92_COL_raw.txt  MBBBIK92_LAM_raw.txt  MBBBIK92_ZEC_raw.txt
# MBBBIK92_DAN_raw.csv  MBBBIK92_LEV_raw.csv  MBBBIK92_ZEP_raw.csv
# MBBBIK92_DAN_raw.txt  MBBBIK92_LEV_raw.txt  MBBBIK92_ZEP_raw.txt
# MBBBIK92_DEU_raw.csv  MBBBIK92_LJE_raw.csv
# MBBBIK92_DEU_raw.txt  MBBBIK92_LJE_raw.txt
#
# /content/data/unzipped/segmented/by_verse/Cebuano:
# ABCEB_1CH_raw.csv  ABCEB_3JN_raw.txt  ABCEB_HOS_raw.csv  ABCEB_MIC_raw.txt
# ABCEB_1CH_raw.txt  ABCEB_ACT_raw.csv  ABCEB_HOS_raw.txt  ABCEB_MRK_raw.csv
# ABCEB_1CO_raw.csv  ABCEB_ACT_raw.txt  ABCEB_ISA_raw.csv  ABCEB_MRK_raw.txt
# ABCEB_1CO_raw.txt  ABCEB_AMO_raw.csv  ABCEB_ISA_raw.txt  ABCEB_NAM_raw.csv
# ABCEB_1JN_raw.csv  ABCEB_AMO_raw.txt  ABCEB_JAS_raw.csv  ABCEB_NAM_raw.txt
# ABCEB_1JN_raw.txt  ABCEB_COL_raw.csv  ABCEB_JAS_raw.txt  ABCEB_NEH_raw.csv
# ABCEB_1KI_raw.csv  ABCEB_COL_raw.txt  ABCEB_JDG_raw.csv  ABCEB_NEH_raw.txt
# ABCEB_1KI_raw.txt  ABCEB_DAN_raw.csv  ABCEB_JDG_raw.txt  ABCEB_NUM_raw.csv
# ABCEB_1PE_raw.csv  ABCEB_DAN_raw.txt  ABCEB_JER_raw.csv  ABCEB_NUM_raw.txt
# ABCEB_1PE_raw.txt  ABCEB_DEU_raw.csv  ABCEB_JER_raw.txt  ABCEB_OBA_raw.csv
# ABCEB_1SA_raw.csv  ABCEB_DEU_raw.txt  ABCEB_JHN_raw.csv  ABCEB_OBA_raw.txt
# ABCEB_1SA_raw.txt  ABCEB_ECC_raw.csv  ABCEB_JHN_raw.txt  ABCEB_PHM_raw.csv
# ABCEB_1TH_raw.csv  ABCEB_ECC_raw.txt  ABCEB_JOB_raw.csv  ABCEB_PHM_raw.txt
# ABCEB_1TH_raw.txt  ABCEB_EPH_raw.csv  ABCEB_JOB_raw.txt  ABCEB_PHP_raw.csv
# ABCEB_1TI_raw.csv  ABCEB_EPH_raw.txt  ABCEB_JOL_raw.csv  ABCEB_PHP_raw.txt
# ABCEB_1TI_raw.txt  ABCEB_EST_raw.csv  ABCEB_JOL_raw.txt  ABCEB_PRO_raw.csv
# ABCEB_2CH_raw.csv  ABCEB_EST_raw.txt  ABCEB_JON_raw.csv  ABCEB_PRO_raw.txt
# ABCEB_2CH_raw.txt  ABCEB_EXO_raw.csv  ABCEB_JON_raw.txt  ABCEB_PSA_raw.csv
# ABCEB_2CO_raw.csv  ABCEB_EXO_raw.txt  ABCEB_JOS_raw.csv  ABCEB_PSA_raw.txt
# ABCEB_2CO_raw.txt  ABCEB_EZK_raw.csv  ABCEB_JOS_raw.txt  ABCEB_REV_raw.csv
# ABCEB_2JN_raw.csv  ABCEB_EZK_raw.txt  ABCEB_JUD_raw.csv  ABCEB_REV_raw.txt
# ABCEB_2JN_raw.txt  ABCEB_EZR_raw.csv  ABCEB_JUD_raw.txt  ABCEB_ROM_raw.csv
# ABCEB_2KI_raw.csv  ABCEB_EZR_raw.txt  ABCEB_LAM_raw.csv  ABCEB_ROM_raw.txt
# ABCEB_2KI_raw.txt  ABCEB_GAL_raw.csv  ABCEB_LAM_raw.txt  ABCEB_RUT_raw.csv
# ABCEB_2PE_raw.csv  ABCEB_GAL_raw.txt  ABCEB_LEV_raw.csv  ABCEB_RUT_raw.txt
# ABCEB_2PE_raw.txt  ABCEB_GEN_raw.csv  ABCEB_LEV_raw.txt  ABCEB_SNG_raw.csv
# ABCEB_2SA_raw.csv  ABCEB_GEN_raw.txt  ABCEB_LUK_raw.csv  ABCEB_SNG_raw.txt
# ABCEB_2SA_raw.txt  ABCEB_HAB_raw.csv  ABCEB_LUK_raw.txt  ABCEB_TIT_raw.csv
# ABCEB_2TH_raw.csv  ABCEB_HAB_raw.txt  ABCEB_MAL_raw.csv  ABCEB_TIT_raw.txt
# ABCEB_2TH_raw.txt  ABCEB_HAG_raw.csv  ABCEB_MAL_raw.txt  ABCEB_ZEC_raw.csv
# ABCEB_2TI_raw.csv  ABCEB_HAG_raw.txt  ABCEB_MAT_raw.csv  ABCEB_ZEC_raw.txt
# ABCEB_2TI_raw.txt  ABCEB_HEB_raw.csv  ABCEB_MAT_raw.txt  ABCEB_ZEP_raw.csv
# ABCEB_3JN_raw.csv  ABCEB_HEB_raw.txt  ABCEB_MIC_raw.csv  ABCEB_ZEP_raw.txt
#
# /content/data/unzipped/segmented/by_verse/Chavacano:
# CBKNT_1CO_raw.csv  CBKNT_2PE_raw.csv  CBKNT_GAL_raw.csv  CBKNT_MRK_raw.csv
# CBKNT_1CO_raw.txt  CBKNT_2PE_raw.txt  CBKNT_GAL_raw.txt  CBKNT_MRK_raw.txt
# CBKNT_1JN_raw.csv  CBKNT_2TH_raw.csv  CBKNT_HEB_raw.csv  CBKNT_PHM_raw.csv
# CBKNT_1JN_raw.txt  CBKNT_2TH_raw.txt  CBKNT_HEB_raw.txt  CBKNT_PHM_raw.txt
# CBKNT_1PE_raw.csv  CBKNT_2TI_raw.csv  CBKNT_JAS_raw.csv  CBKNT_PHP_raw.csv
# CBKNT_1PE_raw.txt  CBKNT_2TI_raw.txt  CBKNT_JAS_raw.txt  CBKNT_PHP_raw.txt
# CBKNT_1TH_raw.csv  CBKNT_3JN_raw.csv  CBKNT_JHN_raw.csv  CBKNT_REV_raw.csv
# CBKNT_1TH_raw.txt  CBKNT_3JN_raw.txt  CBKNT_JHN_raw.txt  CBKNT_REV_raw.txt
# CBKNT_1TI_raw.csv  CBKNT_ACT_raw.csv  CBKNT_JUD_raw.csv  CBKNT_ROM_raw.csv
# CBKNT_1TI_raw.txt  CBKNT_ACT_raw.txt  CBKNT_JUD_raw.txt  CBKNT_ROM_raw.txt
# CBKNT_2CO_raw.csv  CBKNT_COL_raw.csv  CBKNT_LUK_raw.csv  CBKNT_TIT_raw.csv
# CBKNT_2CO_raw.txt  CBKNT_COL_raw.txt  CBKNT_LUK_raw.txt  CBKNT_TIT_raw.txt
# CBKNT_2JN_raw.csv  CBKNT_EPH_raw.csv  CBKNT_MAT_raw.csv
# CBKNT_2JN_raw.txt  CBKNT_EPH_raw.txt  CBKNT_MAT_raw.txt
#
# /content/data/unzipped/segmented/by_verse/Ilokano:
# RIPV_1CH_raw.csv  RIPV_3JN_raw.txt  RIPV_HOS_raw.csv  RIPV_MIC_raw.txt
# RIPV_1CH_raw.txt  RIPV_ACT_raw.csv  RIPV_HOS_raw.txt  RIPV_MRK_raw.csv
# RIPV_1CO_raw.csv  RIPV_ACT_raw.txt  RIPV_ISA_raw.csv  RIPV_MRK_raw.txt
# RIPV_1CO_raw.txt  RIPV_AMO_raw.csv  RIPV_ISA_raw.txt  RIPV_NAM_raw.csv
# RIPV_1JN_raw.csv  RIPV_AMO_raw.txt  RIPV_JAS_raw.csv  RIPV_NAM_raw.txt
# RIPV_1JN_raw.txt  RIPV_COL_raw.csv  RIPV_JAS_raw.txt  RIPV_NEH_raw.csv
# RIPV_1KI_raw.csv  RIPV_COL_raw.txt  RIPV_JDG_raw.csv  RIPV_NEH_raw.txt
# RIPV_1KI_raw.txt  RIPV_DAN_raw.csv  RIPV_JDG_raw.txt  RIPV_NUM_raw.csv
# RIPV_1PE_raw.csv  RIPV_DAN_raw.txt  RIPV_JER_raw.csv  RIPV_NUM_raw.txt
# RIPV_1PE_raw.txt  RIPV_DEU_raw.csv  RIPV_JER_raw.txt  RIPV_OBA_raw.csv
# RIPV_1SA_raw.csv  RIPV_DEU_raw.txt  RIPV_JHN_raw.csv  RIPV_OBA_raw.txt
# RIPV_1SA_raw.txt  RIPV_ECC_raw.csv  RIPV_JHN_raw.txt  RIPV_PHM_raw.csv
# RIPV_1TH_raw.csv  RIPV_ECC_raw.txt  RIPV_JOB_raw.csv  RIPV_PHM_raw.txt
# RIPV_1TH_raw.txt  RIPV_EPH_raw.csv  RIPV_JOB_raw.txt  RIPV_PHP_raw.csv
# RIPV_1TI_raw.csv  RIPV_EPH_raw.txt  RIPV_JOL_raw.csv  RIPV_PHP_raw.txt
# RIPV_1TI_raw.txt  RIPV_EST_raw.csv  RIPV_JOL_raw.txt  RIPV_PRO_raw.csv
# RIPV_2CH_raw.csv  RIPV_EST_raw.txt  RIPV_JON_raw.csv  RIPV_PRO_raw.txt
# RIPV_2CH_raw.txt  RIPV_EXO_raw.csv  RIPV_JON_raw.txt  RIPV_PSA_raw.csv
# RIPV_2CO_raw.csv  RIPV_EXO_raw.txt  RIPV_JOS_raw.csv  RIPV_PSA_raw.txt
# RIPV_2CO_raw.txt  RIPV_EZK_raw.csv  RIPV_JOS_raw.txt  RIPV_REV_raw.csv
# RIPV_2JN_raw.csv  RIPV_EZK_raw.txt  RIPV_JUD_raw.csv  RIPV_REV_raw.txt
# RIPV_2JN_raw.txt  RIPV_EZR_raw.csv  RIPV_JUD_raw.txt  RIPV_ROM_raw.csv
# RIPV_2KI_raw.csv  RIPV_EZR_raw.txt  RIPV_LAM_raw.csv  RIPV_ROM_raw.txt
# RIPV_2KI_raw.txt  RIPV_GAL_raw.csv  RIPV_LAM_raw.txt  RIPV_RUT_raw.csv
# RIPV_2PE_raw.csv  RIPV_GAL_raw.txt  RIPV_LEV_raw.csv  RIPV_RUT_raw.txt
# RIPV_2PE_raw.txt  RIPV_GEN_raw.csv  RIPV_LEV_raw.txt  RIPV_SNG_raw.csv
# RIPV_2SA_raw.csv  RIPV_GEN_raw.txt  RIPV_LUK_raw.csv  RIPV_SNG_raw.txt
# RIPV_2SA_raw.txt  RIPV_HAB_raw.csv  RIPV_LUK_raw.txt  RIPV_TIT_raw.csv
# RIPV_2TH_raw.csv  RIPV_HAB_raw.txt  RIPV_MAL_raw.csv  RIPV_TIT_raw.txt
# RIPV_2TH_raw.txt  RIPV_HAG_raw.csv  RIPV_MAL_raw.txt  RIPV_ZEC_raw.csv
# RIPV_2TI_raw.csv  RIPV_HAG_raw.txt  RIPV_MAT_raw.csv  RIPV_ZEC_raw.txt
# RIPV_2TI_raw.txt  RIPV_HEB_raw.csv  RIPV_MAT_raw.txt  RIPV_ZEP_raw.csv
# RIPV_3JN_raw.csv  RIPV_HEB_raw.txt  RIPV_MIC_raw.csv  RIPV_ZEP_raw.txt
#
# /content/data/unzipped/segmented/by_verse/Isnag:
# ISDNT_1CO_raw.csv  ISDNT_2PE_raw.txt  ISDNT_GAL_raw.csv  ISDNT_MAT_raw.txt
# ISDNT_1CO_raw.txt  ISDNT_2TH_raw.csv  ISDNT_GAL_raw.txt  ISDNT_MRK_raw.csv
# ISDNT_1JN_raw.csv  ISDNT_2TH_raw.txt  ISDNT_GEN_raw.csv  ISDNT_MRK_raw.txt
# ISDNT_1JN_raw.txt  ISDNT_2TI_raw.csv  ISDNT_GEN_raw.txt  ISDNT_PHM_raw.csv
# ISDNT_1PE_raw.csv  ISDNT_2TI_raw.txt  ISDNT_HEB_raw.csv  ISDNT_PHM_raw.txt
# ISDNT_1PE_raw.txt  ISDNT_3JN_raw.csv  ISDNT_HEB_raw.txt  ISDNT_PHP_raw.csv
# ISDNT_1TH_raw.csv  ISDNT_3JN_raw.txt  ISDNT_JAS_raw.csv  ISDNT_PHP_raw.txt
# ISDNT_1TH_raw.txt  ISDNT_ACT_raw.csv  ISDNT_JAS_raw.txt  ISDNT_REV_raw.csv
# ISDNT_1TI_raw.csv  ISDNT_ACT_raw.txt  ISDNT_JHN_raw.csv  ISDNT_REV_raw.txt
# ISDNT_1TI_raw.txt  ISDNT_COL_raw.csv  ISDNT_JHN_raw.txt  ISDNT_ROM_raw.csv
# ISDNT_2CO_raw.csv  ISDNT_COL_raw.txt  ISDNT_JUD_raw.csv  ISDNT_ROM_raw.txt
# ISDNT_2CO_raw.txt  ISDNT_EPH_raw.csv  ISDNT_JUD_raw.txt  ISDNT_TIT_raw.csv
# ISDNT_2JN_raw.csv  ISDNT_EPH_raw.txt  ISDNT_LUK_raw.csv  ISDNT_TIT_raw.txt
# ISDNT_2JN_raw.txt  ISDNT_EXO_raw.csv  ISDNT_LUK_raw.txt
# ISDNT_2PE_raw.csv  ISDNT_EXO_raw.txt  ISDNT_MAT_raw.csv
#
# /content/data/unzipped/segmented/by_verse/Ivatan:
# VTSP_1CO_raw.csv  VTSP_2PE_raw.txt  VTSP_HEB_raw.csv  VTSP_PHM_raw.txt
# VTSP_1CO_raw.txt  VTSP_2TH_raw.csv  VTSP_HEB_raw.txt  VTSP_PHP_raw.csv
# VTSP_1JN_raw.csv  VTSP_2TH_raw.txt  VTSP_JAS_raw.csv  VTSP_PHP_raw.txt
# VTSP_1JN_raw.txt  VTSP_2TI_raw.csv  VTSP_JAS_raw.txt  VTSP_PRO_raw.csv
# VTSP_1PE_raw.csv  VTSP_2TI_raw.txt  VTSP_JHN_raw.csv  VTSP_PRO_raw.txt
# VTSP_1PE_raw.txt  VTSP_3JN_raw.csv  VTSP_JHN_raw.txt  VTSP_PSA_raw.csv
# VTSP_1TH_raw.csv  VTSP_3JN_raw.txt  VTSP_JUD_raw.csv  VTSP_PSA_raw.txt
# VTSP_1TH_raw.txt  VTSP_ACT_raw.csv  VTSP_JUD_raw.txt  VTSP_REV_raw.csv
# VTSP_1TI_raw.csv  VTSP_ACT_raw.txt  VTSP_LUK_raw.csv  VTSP_REV_raw.txt
# VTSP_1TI_raw.txt  VTSP_COL_raw.csv  VTSP_LUK_raw.txt  VTSP_ROM_raw.csv
# VTSP_2CO_raw.csv  VTSP_COL_raw.txt  VTSP_MAT_raw.csv  VTSP_ROM_raw.txt
# VTSP_2CO_raw.txt  VTSP_EPH_raw.csv  VTSP_MAT_raw.txt  VTSP_TIT_raw.csv
# VTSP_2JN_raw.csv  VTSP_EPH_raw.txt  VTSP_MRK_raw.csv  VTSP_TIT_raw.txt
# VTSP_2JN_raw.txt  VTSP_GAL_raw.csv  VTSP_MRK_raw.txt
# VTSP_2PE_raw.csv  VTSP_GAL_raw.txt  VTSP_PHM_raw.csv
#
# /content/data/unzipped/segmented/by_verse/Kalinga:
# kmk_1CO_raw.csv  kmk_2PE_raw.csv  kmk_GAL_raw.csv  kmk_MRK_raw.csv
# kmk_1CO_raw.txt  kmk_2PE_raw.txt  kmk_GAL_raw.txt  kmk_MRK_raw.txt
# kmk_1JN_raw.csv  kmk_2TH_raw.csv  kmk_HEB_raw.csv  kmk_PHM_raw.csv
# kmk_1JN_raw.txt  kmk_2TH_raw.txt  kmk_HEB_raw.txt  kmk_PHM_raw.txt
# kmk_1PE_raw.csv  kmk_2TI_raw.csv  kmk_JAS_raw.csv  kmk_PHP_raw.csv
# kmk_1PE_raw.txt  kmk_2TI_raw.txt  kmk_JAS_raw.txt  kmk_PHP_raw.txt
# kmk_1TH_raw.csv  kmk_3JN_raw.csv  kmk_JHN_raw.csv  kmk_REV_raw.csv
# kmk_1TH_raw.txt  kmk_3JN_raw.txt  kmk_JHN_raw.txt  kmk_REV_raw.txt
# kmk_1TI_raw.csv  kmk_ACT_raw.csv  kmk_JUD_raw.csv  kmk_ROM_raw.csv
# kmk_1TI_raw.txt  kmk_ACT_raw.txt  kmk_JUD_raw.txt  kmk_ROM_raw.txt
# kmk_2CO_raw.csv  kmk_COL_raw.csv  kmk_LUK_raw.csv  kmk_TIT_raw.csv
# kmk_2CO_raw.txt  kmk_COL_raw.txt  kmk_LUK_raw.txt  kmk_TIT_raw.txt
# kmk_2JN_raw.csv  kmk_EPH_raw.csv  kmk_MAT_raw.csv
# kmk_2JN_raw.txt  kmk_EPH_raw.txt  kmk_MAT_raw.txt
#
# /content/data/unzipped/segmented/by_verse/Kankanaey:
# XNN_1CO_raw.csv  XNN_3JN_raw.txt  XNN_ISA_raw.csv  XNN_MIC_raw.txt
# XNN_1CO_raw.txt  XNN_ACT_raw.csv  XNN_ISA_raw.txt  XNN_MRK_raw.csv
# XNN_1JN_raw.csv  XNN_ACT_raw.txt  XNN_JAS_raw.csv  XNN_MRK_raw.txt
# XNN_1JN_raw.txt  XNN_AMO_raw.csv  XNN_JAS_raw.txt  XNN_NEH_raw.csv
# XNN_1KI_raw.csv  XNN_AMO_raw.txt  XNN_JDG_raw.csv  XNN_NEH_raw.txt
# XNN_1KI_raw.txt  XNN_BAR_raw.csv  XNN_JDG_raw.txt  XNN_NUM_raw.csv
# XNN_1PE_raw.csv  XNN_BAR_raw.txt  XNN_JDT_raw.csv  XNN_NUM_raw.txt
# XNN_1PE_raw.txt  XNN_COL_raw.csv  XNN_JDT_raw.txt  XNN_PHM_raw.csv
# XNN_1SA_raw.csv  XNN_COL_raw.txt  XNN_JER_raw.csv  XNN_PHM_raw.txt
# XNN_1SA_raw.txt  XNN_DAN_raw.csv  XNN_JER_raw.txt  XNN_PHP_raw.csv
# XNN_1TH_raw.csv  XNN_DAN_raw.txt  XNN_JHN_raw.csv  XNN_PHP_raw.txt
# XNN_1TH_raw.txt  XNN_DEU_raw.csv  XNN_JHN_raw.txt  XNN_PRO_raw.csv
# XNN_1TI_raw.csv  XNN_DEU_raw.txt  XNN_JOB_raw.csv  XNN_PRO_raw.txt
# XNN_1TI_raw.txt  XNN_ECC_raw.csv  XNN_JOB_raw.txt  XNN_PSA_raw.csv
# XNN_2CH_raw.csv  XNN_ECC_raw.txt  XNN_JOL_raw.csv  XNN_PSA_raw.txt
# XNN_2CH_raw.txt  XNN_EPH_raw.csv  XNN_JOL_raw.txt  XNN_REV_raw.csv
# XNN_2CO_raw.csv  XNN_EPH_raw.txt  XNN_JON_raw.csv  XNN_REV_raw.txt
# XNN_2CO_raw.txt  XNN_EXO_raw.csv  XNN_JON_raw.txt  XNN_ROM_raw.csv
# XNN_2JN_raw.csv  XNN_EXO_raw.txt  XNN_JOS_raw.csv  XNN_ROM_raw.txt
# XNN_2JN_raw.txt  XNN_EZK_raw.csv  XNN_JOS_raw.txt  XNN_RUT_raw.csv
# XNN_2KI_raw.csv  XNN_EZK_raw.txt  XNN_JUD_raw.csv  XNN_RUT_raw.txt
# XNN_2KI_raw.txt  XNN_GAL_raw.csv  XNN_JUD_raw.txt  XNN_SIR_raw.csv
# XNN_2PE_raw.csv  XNN_GAL_raw.txt  XNN_LEV_raw.csv  XNN_SIR_raw.txt
# XNN_2PE_raw.txt  XNN_GEN_raw.csv  XNN_LEV_raw.txt  XNN_TIT_raw.csv
# XNN_2SA_raw.csv  XNN_GEN_raw.txt  XNN_LUK_raw.csv  XNN_TIT_raw.txt
# XNN_2SA_raw.txt  XNN_HAB_raw.csv  XNN_LUK_raw.txt  XNN_WIS_raw.csv
# XNN_2TH_raw.csv  XNN_HAB_raw.txt  XNN_MAL_raw.csv  XNN_WIS_raw.txt
# XNN_2TH_raw.txt  XNN_HEB_raw.csv  XNN_MAL_raw.txt  XNN_ZEC_raw.csv
# XNN_2TI_raw.csv  XNN_HEB_raw.txt  XNN_MAT_raw.csv  XNN_ZEC_raw.txt
# XNN_2TI_raw.txt  XNN_HOS_raw.csv  XNN_MAT_raw.txt  XNN_ZEP_raw.csv
# XNN_3JN_raw.csv  XNN_HOS_raw.txt  XNN_MIC_raw.csv  XNN_ZEP_raw.txt
#
# /content/data/unzipped/segmented/by_verse/Kapampangan:
# PmPV_1CH_raw.csv  PmPV_ACT_raw.txt  PmPV_JAS_raw.csv  PmPV_NEH_raw.txt
# PmPV_1CH_raw.txt  PmPV_AMO_raw.csv  PmPV_JAS_raw.txt  PmPV_NUM_raw.csv
# PmPV_1CO_raw.csv  PmPV_AMO_raw.txt  PmPV_JDG_raw.csv  PmPV_NUM_raw.txt
# PmPV_1CO_raw.txt  PmPV_BAR_raw.csv  PmPV_JDG_raw.txt  PmPV_OBA_raw.csv
# PmPV_1JN_raw.csv  PmPV_BAR_raw.txt  PmPV_JDT_raw.csv  PmPV_OBA_raw.txt
# PmPV_1JN_raw.txt  PmPV_BEL_raw.csv  PmPV_JDT_raw.txt  PmPV_PHM_raw.csv
# PmPV_1KI_raw.csv  PmPV_BEL_raw.txt  PmPV_JER_raw.csv  PmPV_PHM_raw.txt
# PmPV_1KI_raw.txt  PmPV_COL_raw.csv  PmPV_JER_raw.txt  PmPV_PHP_raw.csv
# PmPV_1MA_raw.csv  PmPV_COL_raw.txt  PmPV_JHN_raw.csv  PmPV_PHP_raw.txt
# PmPV_1MA_raw.txt  PmPV_DAN_raw.csv  PmPV_JHN_raw.txt  PmPV_PRO_raw.csv
# PmPV_1PE_raw.csv  PmPV_DAN_raw.txt  PmPV_JOB_raw.csv  PmPV_PRO_raw.txt
# PmPV_1PE_raw.txt  PmPV_DEU_raw.csv  PmPV_JOB_raw.txt  PmPV_PSA_raw.csv
# PmPV_1SA_raw.csv  PmPV_DEU_raw.txt  PmPV_JOL_raw.csv  PmPV_PSA_raw.txt
# PmPV_1SA_raw.txt  PmPV_ECC_raw.csv  PmPV_JOL_raw.txt  PmPV_REV_raw.csv
# PmPV_1TH_raw.csv  PmPV_ECC_raw.txt  PmPV_JON_raw.csv  PmPV_REV_raw.txt
# PmPV_1TH_raw.txt  PmPV_EPH_raw.csv  PmPV_JON_raw.txt  PmPV_ROM_raw.csv
# PmPV_1TI_raw.csv  PmPV_EPH_raw.txt  PmPV_JOS_raw.csv  PmPV_ROM_raw.txt
# PmPV_1TI_raw.txt  PmPV_EST_raw.csv  PmPV_JOS_raw.txt  PmPV_RUT_raw.csv
# PmPV_2CH_raw.csv  PmPV_EST_raw.txt  PmPV_JUD_raw.csv  PmPV_RUT_raw.txt
# PmPV_2CH_raw.txt  PmPV_EXO_raw.csv  PmPV_JUD_raw.txt  PmPV_S3Y_raw.csv
# PmPV_2CO_raw.csv  PmPV_EXO_raw.txt  PmPV_LAM_raw.csv  PmPV_S3Y_raw.txt
# PmPV_2CO_raw.txt  PmPV_EZK_raw.csv  PmPV_LAM_raw.txt  PmPV_SIR_raw.csv
# PmPV_2JN_raw.csv  PmPV_EZK_raw.txt  PmPV_LEV_raw.csv  PmPV_SIR_raw.txt
# PmPV_2JN_raw.txt  PmPV_EZR_raw.csv  PmPV_LEV_raw.txt  PmPV_SNG_raw.csv
# PmPV_2KI_raw.csv  PmPV_EZR_raw.txt  PmPV_LJE_raw.csv  PmPV_SNG_raw.txt
# PmPV_2KI_raw.txt  PmPV_GAL_raw.csv  PmPV_LJE_raw.txt  PmPV_SUS_raw.csv
# PmPV_2MA_raw.csv  PmPV_GAL_raw.txt  PmPV_LUK_raw.csv  PmPV_SUS_raw.txt
# PmPV_2MA_raw.txt  PmPV_GEN_raw.csv  PmPV_LUK_raw.txt  PmPV_TIT_raw.csv
# PmPV_2PE_raw.csv  PmPV_GEN_raw.txt  PmPV_MAL_raw.csv  PmPV_TIT_raw.txt
# PmPV_2PE_raw.txt  PmPV_HAB_raw.csv  PmPV_MAL_raw.txt  PmPV_TOB_raw.csv
# PmPV_2SA_raw.csv  PmPV_HAB_raw.txt  PmPV_MAT_raw.csv  PmPV_TOB_raw.txt
# PmPV_2SA_raw.txt  PmPV_HAG_raw.csv  PmPV_MAT_raw.txt  PmPV_WIS_raw.csv
# PmPV_2TH_raw.csv  PmPV_HAG_raw.txt  PmPV_MIC_raw.csv  PmPV_WIS_raw.txt
# PmPV_2TH_raw.txt  PmPV_HEB_raw.csv  PmPV_MIC_raw.txt  PmPV_ZEC_raw.csv
# PmPV_2TI_raw.csv  PmPV_HEB_raw.txt  PmPV_MRK_raw.csv  PmPV_ZEC_raw.txt
# PmPV_2TI_raw.txt  PmPV_HOS_raw.csv  PmPV_MRK_raw.txt  PmPV_ZEP_raw.csv
# PmPV_3JN_raw.csv  PmPV_HOS_raw.txt  PmPV_NAM_raw.csv  PmPV_ZEP_raw.txt
# PmPV_3JN_raw.txt  PmPV_ISA_raw.csv  PmPV_NAM_raw.txt
# PmPV_ACT_raw.csv  PmPV_ISA_raw.txt  PmPV_NEH_raw.csv
#
# /content/data/unzipped/segmented/by_verse/Pangasinense:
# PNPV_1CH_raw.csv  PNPV_ACT_raw.txt  PNPV_JAS_raw.csv  PNPV_NEH_raw.txt
# PNPV_1CH_raw.txt  PNPV_AMO_raw.csv  PNPV_JAS_raw.txt  PNPV_NUM_raw.csv
# PNPV_1CO_raw.csv  PNPV_AMO_raw.txt  PNPV_JDG_raw.csv  PNPV_NUM_raw.txt
# PNPV_1CO_raw.txt  PNPV_BAR_raw.csv  PNPV_JDG_raw.txt  PNPV_OBA_raw.csv
# PNPV_1JN_raw.csv  PNPV_BAR_raw.txt  PNPV_JDT_raw.csv  PNPV_OBA_raw.txt
# PNPV_1JN_raw.txt  PNPV_BEL_raw.csv  PNPV_JDT_raw.txt  PNPV_PHM_raw.csv
# PNPV_1KI_raw.csv  PNPV_BEL_raw.txt  PNPV_JER_raw.csv  PNPV_PHM_raw.txt
# PNPV_1KI_raw.txt  PNPV_COL_raw.csv  PNPV_JER_raw.txt  PNPV_PHP_raw.csv
# PNPV_1MA_raw.csv  PNPV_COL_raw.txt  PNPV_JHN_raw.csv  PNPV_PHP_raw.txt
# PNPV_1MA_raw.txt  PNPV_DAN_raw.csv  PNPV_JHN_raw.txt  PNPV_PRO_raw.csv
# PNPV_1PE_raw.csv  PNPV_DAN_raw.txt  PNPV_JOB_raw.csv  PNPV_PRO_raw.txt
# PNPV_1PE_raw.txt  PNPV_DEU_raw.csv  PNPV_JOB_raw.txt  PNPV_PSA_raw.csv
# PNPV_1SA_raw.csv  PNPV_DEU_raw.txt  PNPV_JOL_raw.csv  PNPV_PSA_raw.txt
# PNPV_1SA_raw.txt  PNPV_ECC_raw.csv  PNPV_JOL_raw.txt  PNPV_REV_raw.csv
# PNPV_1TH_raw.csv  PNPV_ECC_raw.txt  PNPV_JON_raw.csv  PNPV_REV_raw.txt
# PNPV_1TH_raw.txt  PNPV_EPH_raw.csv  PNPV_JON_raw.txt  PNPV_ROM_raw.csv
# PNPV_1TI_raw.csv  PNPV_EPH_raw.txt  PNPV_JOS_raw.csv  PNPV_ROM_raw.txt
# PNPV_1TI_raw.txt  PNPV_EST_raw.csv  PNPV_JOS_raw.txt  PNPV_RUT_raw.csv
# PNPV_2CH_raw.csv  PNPV_EST_raw.txt  PNPV_JUD_raw.csv  PNPV_RUT_raw.txt
# PNPV_2CH_raw.txt  PNPV_EXO_raw.csv  PNPV_JUD_raw.txt  PNPV_S3Y_raw.csv
# PNPV_2CO_raw.csv  PNPV_EXO_raw.txt  PNPV_LAM_raw.csv  PNPV_S3Y_raw.txt
# PNPV_2CO_raw.txt  PNPV_EZK_raw.csv  PNPV_LAM_raw.txt  PNPV_SIR_raw.csv
# PNPV_2JN_raw.csv  PNPV_EZK_raw.txt  PNPV_LEV_raw.csv  PNPV_SIR_raw.txt
# PNPV_2JN_raw.txt  PNPV_EZR_raw.csv  PNPV_LEV_raw.txt  PNPV_SNG_raw.csv
# PNPV_2KI_raw.csv  PNPV_EZR_raw.txt  PNPV_LJE_raw.csv  PNPV_SNG_raw.txt
# PNPV_2KI_raw.txt  PNPV_GAL_raw.csv  PNPV_LJE_raw.txt  PNPV_SUS_raw.csv
# PNPV_2MA_raw.csv  PNPV_GAL_raw.txt  PNPV_LUK_raw.csv  PNPV_SUS_raw.txt
# PNPV_2MA_raw.txt  PNPV_GEN_raw.csv  PNPV_LUK_raw.txt  PNPV_TIT_raw.csv
# PNPV_2PE_raw.csv  PNPV_GEN_raw.txt  PNPV_MAL_raw.csv  PNPV_TIT_raw.txt
# PNPV_2PE_raw.txt  PNPV_HAB_raw.csv  PNPV_MAL_raw.txt  PNPV_TOB_raw.csv
# PNPV_2SA_raw.csv  PNPV_HAB_raw.txt  PNPV_MAT_raw.csv  PNPV_TOB_raw.txt
# PNPV_2SA_raw.txt  PNPV_HAG_raw.csv  PNPV_MAT_raw.txt  PNPV_WIS_raw.csv
# PNPV_2TH_raw.csv  PNPV_HAG_raw.txt  PNPV_MIC_raw.csv  PNPV_WIS_raw.txt
# PNPV_2TH_raw.txt  PNPV_HEB_raw.csv  PNPV_MIC_raw.txt  PNPV_ZEC_raw.csv
# PNPV_2TI_raw.csv  PNPV_HEB_raw.txt  PNPV_MRK_raw.csv  PNPV_ZEC_raw.txt
# PNPV_2TI_raw.txt  PNPV_HOS_raw.csv  PNPV_MRK_raw.txt  PNPV_ZEP_raw.csv
# PNPV_3JN_raw.csv  PNPV_HOS_raw.txt  PNPV_NAM_raw.csv  PNPV_ZEP_raw.txt
# PNPV_3JN_raw.txt  PNPV_ISA_raw.csv  PNPV_NAM_raw.txt
# PNPV_ACT_raw.csv  PNPV_ISA_raw.txt  PNPV_NEH_raw.csv
#
# /content/data/unzipped/segmented/by_verse/Sambal:
# XSB_1CO_raw.csv  XSB_2PE_raw.csv  XSB_GAL_raw.csv  XSB_MRK_raw.csv
# XSB_1CO_raw.txt  XSB_2PE_raw.txt  XSB_GAL_raw.txt  XSB_MRK_raw.txt
# XSB_1JN_raw.csv  XSB_2TH_raw.csv  XSB_HEB_raw.csv  XSB_PHM_raw.csv
# XSB_1JN_raw.txt  XSB_2TH_raw.txt  XSB_HEB_raw.txt  XSB_PHM_raw.txt
# XSB_1PE_raw.csv  XSB_2TI_raw.csv  XSB_JAS_raw.csv  XSB_PHP_raw.csv
# XSB_1PE_raw.txt  XSB_2TI_raw.txt  XSB_JAS_raw.txt  XSB_PHP_raw.txt
# XSB_1TH_raw.csv  XSB_3JN_raw.csv  XSB_JHN_raw.csv  XSB_REV_raw.csv
# XSB_1TH_raw.txt  XSB_3JN_raw.txt  XSB_JHN_raw.txt  XSB_REV_raw.txt
# XSB_1TI_raw.csv  XSB_ACT_raw.csv  XSB_JUD_raw.csv  XSB_ROM_raw.csv
# XSB_1TI_raw.txt  XSB_ACT_raw.txt  XSB_JUD_raw.txt  XSB_ROM_raw.txt
# XSB_2CO_raw.csv  XSB_COL_raw.csv  XSB_LUK_raw.csv  XSB_TIT_raw.csv
# XSB_2CO_raw.txt  XSB_COL_raw.txt  XSB_LUK_raw.txt  XSB_TIT_raw.txt
# XSB_2JN_raw.csv  XSB_EPH_raw.csv  XSB_MAT_raw.csv
# XSB_2JN_raw.txt  XSB_EPH_raw.txt  XSB_MAT_raw.txt
#
# /content/data/unzipped/segmented/by_verse/Spanish:
# RVR95_1CH_raw.csv  RVR95_3JN_raw.txt  RVR95_HOS_raw.csv  RVR95_MIC_raw.txt
# RVR95_1CH_raw.txt  RVR95_ACT_raw.csv  RVR95_HOS_raw.txt  RVR95_MRK_raw.csv
# RVR95_1CO_raw.csv  RVR95_ACT_raw.txt  RVR95_ISA_raw.csv  RVR95_MRK_raw.txt
# RVR95_1CO_raw.txt  RVR95_AMO_raw.csv  RVR95_ISA_raw.txt  RVR95_NAM_raw.csv
# RVR95_1JN_raw.csv  RVR95_AMO_raw.txt  RVR95_JAS_raw.csv  RVR95_NAM_raw.txt
# RVR95_1JN_raw.txt  RVR95_COL_raw.csv  RVR95_JAS_raw.txt  RVR95_NEH_raw.csv
# RVR95_1KI_raw.csv  RVR95_COL_raw.txt  RVR95_JDG_raw.csv  RVR95_NEH_raw.txt
# RVR95_1KI_raw.txt  RVR95_DAN_raw.csv  RVR95_JDG_raw.txt  RVR95_NUM_raw.csv
# RVR95_1PE_raw.csv  RVR95_DAN_raw.txt  RVR95_JER_raw.csv  RVR95_NUM_raw.txt
# RVR95_1PE_raw.txt  RVR95_DEU_raw.csv  RVR95_JER_raw.txt  RVR95_OBA_raw.csv
# RVR95_1SA_raw.csv  RVR95_DEU_raw.txt  RVR95_JHN_raw.csv  RVR95_OBA_raw.txt
# RVR95_1SA_raw.txt  RVR95_ECC_raw.csv  RVR95_JHN_raw.txt  RVR95_PHM_raw.csv
# RVR95_1TH_raw.csv  RVR95_ECC_raw.txt  RVR95_JOB_raw.csv  RVR95_PHM_raw.txt
# RVR95_1TH_raw.txt  RVR95_EPH_raw.csv  RVR95_JOB_raw.txt  RVR95_PHP_raw.csv
# RVR95_1TI_raw.csv  RVR95_EPH_raw.txt  RVR95_JOL_raw.csv  RVR95_PHP_raw.txt
# RVR95_1TI_raw.txt  RVR95_EST_raw.csv  RVR95_JOL_raw.txt  RVR95_PRO_raw.csv
# RVR95_2CH_raw.csv  RVR95_EST_raw.txt  RVR95_JON_raw.csv  RVR95_PRO_raw.txt
# RVR95_2CH_raw.txt  RVR95_EXO_raw.csv  RVR95_JON_raw.txt  RVR95_PSA_raw.csv
# RVR95_2CO_raw.csv  RVR95_EXO_raw.txt  RVR95_JOS_raw.csv  RVR95_PSA_raw.txt
# RVR95_2CO_raw.txt  RVR95_EZK_raw.csv  RVR95_JOS_raw.txt  RVR95_REV_raw.csv
# RVR95_2JN_raw.csv  RVR95_EZK_raw.txt  RVR95_JUD_raw.csv  RVR95_REV_raw.txt
# RVR95_2JN_raw.txt  RVR95_EZR_raw.csv  RVR95_JUD_raw.txt  RVR95_ROM_raw.csv
# RVR95_2KI_raw.csv  RVR95_EZR_raw.txt  RVR95_LAM_raw.csv  RVR95_ROM_raw.txt
# RVR95_2KI_raw.txt  RVR95_GAL_raw.csv  RVR95_LAM_raw.txt  RVR95_RUT_raw.csv
# RVR95_2PE_raw.csv  RVR95_GAL_raw.txt  RVR95_LEV_raw.csv  RVR95_RUT_raw.txt
# RVR95_2PE_raw.txt  RVR95_GEN_raw.csv  RVR95_LEV_raw.txt  RVR95_SNG_raw.csv
# RVR95_2SA_raw.csv  RVR95_GEN_raw.txt  RVR95_LUK_raw.csv  RVR95_SNG_raw.txt
# RVR95_2SA_raw.txt  RVR95_HAB_raw.csv  RVR95_LUK_raw.txt  RVR95_TIT_raw.csv
# RVR95_2TH_raw.csv  RVR95_HAB_raw.txt  RVR95_MAL_raw.csv  RVR95_TIT_raw.txt
# RVR95_2TH_raw.txt  RVR95_HAG_raw.csv  RVR95_MAL_raw.txt  RVR95_ZEC_raw.csv
# RVR95_2TI_raw.csv  RVR95_HAG_raw.txt  RVR95_MAT_raw.csv  RVR95_ZEC_raw.txt
# RVR95_2TI_raw.txt  RVR95_HEB_raw.csv  RVR95_MAT_raw.txt  RVR95_ZEP_raw.csv
# RVR95_3JN_raw.csv  RVR95_HEB_raw.txt  RVR95_MIC_raw.csv  RVR95_ZEP_raw.txt
#
# /content/data/unzipped/segmented/by_verse/Tagalog:
# MBB05_1CH_raw.csv  MBB05_ACT_raw.txt  MBB05_JAS_raw.csv  MBB05_NEH_raw.txt
# MBB05_1CH_raw.txt  MBB05_AMO_raw.csv  MBB05_JAS_raw.txt  MBB05_NUM_raw.csv
# MBB05_1CO_raw.csv  MBB05_AMO_raw.txt  MBB05_JDG_raw.csv  MBB05_NUM_raw.txt
# MBB05_1CO_raw.txt  MBB05_BAR_raw.csv  MBB05_JDG_raw.txt  MBB05_OBA_raw.csv
# MBB05_1JN_raw.csv  MBB05_BAR_raw.txt  MBB05_JDT_raw.csv  MBB05_OBA_raw.txt
# MBB05_1JN_raw.txt  MBB05_BEL_raw.csv  MBB05_JDT_raw.txt  MBB05_PHM_raw.csv
# MBB05_1KI_raw.csv  MBB05_BEL_raw.txt  MBB05_JER_raw.csv  MBB05_PHM_raw.txt
# MBB05_1KI_raw.txt  MBB05_COL_raw.csv  MBB05_JER_raw.txt  MBB05_PHP_raw.csv
# MBB05_1MA_raw.csv  MBB05_COL_raw.txt  MBB05_JHN_raw.csv  MBB05_PHP_raw.txt
# MBB05_1MA_raw.txt  MBB05_DAN_raw.csv  MBB05_JHN_raw.txt  MBB05_PRO_raw.csv
# MBB05_1PE_raw.csv  MBB05_DAN_raw.txt  MBB05_JOB_raw.csv  MBB05_PRO_raw.txt
# MBB05_1PE_raw.txt  MBB05_DEU_raw.csv  MBB05_JOB_raw.txt  MBB05_PSA_raw.csv
# MBB05_1SA_raw.csv  MBB05_DEU_raw.txt  MBB05_JOL_raw.csv  MBB05_PSA_raw.txt
# MBB05_1SA_raw.txt  MBB05_ECC_raw.csv  MBB05_JOL_raw.txt  MBB05_REV_raw.csv
# MBB05_1TH_raw.csv  MBB05_ECC_raw.txt  MBB05_JON_raw.csv  MBB05_REV_raw.txt
# MBB05_1TH_raw.txt  MBB05_EPH_raw.csv  MBB05_JON_raw.txt  MBB05_ROM_raw.csv
# MBB05_1TI_raw.csv  MBB05_EPH_raw.txt  MBB05_JOS_raw.csv  MBB05_ROM_raw.txt
# MBB05_1TI_raw.txt  MBB05_EST_raw.csv  MBB05_JOS_raw.txt  MBB05_RUT_raw.csv
# MBB05_2CH_raw.csv  MBB05_EST_raw.txt  MBB05_JUD_raw.csv  MBB05_RUT_raw.txt
# MBB05_2CH_raw.txt  MBB05_EXO_raw.csv  MBB05_JUD_raw.txt  MBB05_S3Y_raw.csv
# MBB05_2CO_raw.csv  MBB05_EXO_raw.txt  MBB05_LAM_raw.csv  MBB05_S3Y_raw.txt
# MBB05_2CO_raw.txt  MBB05_EZK_raw.csv  MBB05_LAM_raw.txt  MBB05_SIR_raw.csv
# MBB05_2JN_raw.csv  MBB05_EZK_raw.txt  MBB05_LEV_raw.csv  MBB05_SIR_raw.txt
# MBB05_2JN_raw.txt  MBB05_EZR_raw.csv  MBB05_LEV_raw.txt  MBB05_SNG_raw.csv
# MBB05_2KI_raw.csv  MBB05_EZR_raw.txt  MBB05_LJE_raw.csv  MBB05_SNG_raw.txt
# MBB05_2KI_raw.txt  MBB05_GAL_raw.csv  MBB05_LJE_raw.txt  MBB05_SUS_raw.csv
# MBB05_2MA_raw.csv  MBB05_GAL_raw.txt  MBB05_LUK_raw.csv  MBB05_SUS_raw.txt
# MBB05_2MA_raw.txt  MBB05_GEN_raw.csv  MBB05_LUK_raw.txt  MBB05_TIT_raw.csv
# MBB05_2PE_raw.csv  MBB05_GEN_raw.txt  MBB05_MAL_raw.csv  MBB05_TIT_raw.txt
# MBB05_2PE_raw.txt  MBB05_HAB_raw.csv  MBB05_MAL_raw.txt  MBB05_TOB_raw.csv
# MBB05_2SA_raw.csv  MBB05_HAB_raw.txt  MBB05_MAT_raw.csv  MBB05_TOB_raw.txt
# MBB05_2SA_raw.txt  MBB05_HAG_raw.csv  MBB05_MAT_raw.txt  MBB05_WIS_raw.csv
# MBB05_2TH_raw.csv  MBB05_HAG_raw.txt  MBB05_MIC_raw.csv  MBB05_WIS_raw.txt
# MBB05_2TH_raw.txt  MBB05_HEB_raw.csv  MBB05_MIC_raw.txt  MBB05_ZEC_raw.csv
# MBB05_2TI_raw.csv  MBB05_HEB_raw.txt  MBB05_MRK_raw.csv  MBB05_ZEC_raw.txt
# MBB05_2TI_raw.txt  MBB05_HOS_raw.csv  MBB05_MRK_raw.txt  MBB05_ZEP_raw.csv
# MBB05_3JN_raw.csv  MBB05_HOS_raw.txt  MBB05_NAM_raw.csv  MBB05_ZEP_raw.txt
# MBB05_3JN_raw.txt  MBB05_ISA_raw.csv  MBB05_NAM_raw.txt
# MBB05_ACT_raw.csv  MBB05_ISA_raw.txt  MBB05_NEH_raw.csv
#
# /content/data/unzipped/segmented/by_verse/Tausug:
# TSG_1CO_raw.csv  TSG_2PE_raw.csv  TSG_GAL_raw.csv  TSG_MRK_raw.csv
# TSG_1CO_raw.txt  TSG_2PE_raw.txt  TSG_GAL_raw.txt  TSG_MRK_raw.txt
# TSG_1JN_raw.csv  TSG_2TH_raw.csv  TSG_HEB_raw.csv  TSG_PHM_raw.csv
# TSG_1JN_raw.txt  TSG_2TH_raw.txt  TSG_HEB_raw.txt  TSG_PHM_raw.txt
# TSG_1PE_raw.csv  TSG_2TI_raw.csv  TSG_JAS_raw.csv  TSG_PHP_raw.csv
# TSG_1PE_raw.txt  TSG_2TI_raw.txt  TSG_JAS_raw.txt  TSG_PHP_raw.txt
# TSG_1TH_raw.csv  TSG_3JN_raw.csv  TSG_JHN_raw.csv  TSG_REV_raw.csv
# TSG_1TH_raw.txt  TSG_3JN_raw.txt  TSG_JHN_raw.txt  TSG_REV_raw.txt
# TSG_1TI_raw.csv  TSG_ACT_raw.csv  TSG_JUD_raw.csv  TSG_ROM_raw.csv
# TSG_1TI_raw.txt  TSG_ACT_raw.txt  TSG_JUD_raw.txt  TSG_ROM_raw.txt
# TSG_2CO_raw.csv  TSG_COL_raw.csv  TSG_LUK_raw.csv  TSG_TIT_raw.csv
# TSG_2CO_raw.txt  TSG_COL_raw.txt  TSG_LUK_raw.txt  TSG_TIT_raw.txt
# TSG_2JN_raw.csv  TSG_EPH_raw.csv  TSG_MAT_raw.csv
# TSG_2JN_raw.txt  TSG_EPH_raw.txt  TSG_MAT_raw.txt
#
# /content/data/unzipped/segmented/by_verse/Yakan:
# YAKV_1CO_raw.csv  YAKV_2PE_raw.txt  YAKV_GEN_raw.csv  YAKV_MAT_raw.txt
# YAKV_1CO_raw.txt  YAKV_2TH_raw.csv  YAKV_GEN_raw.txt  YAKV_MRK_raw.csv
# YAKV_1JN_raw.csv  YAKV_2TH_raw.txt  YAKV_HEB_raw.csv  YAKV_MRK_raw.txt
# YAKV_1JN_raw.txt  YAKV_2TI_raw.csv  YAKV_HEB_raw.txt  YAKV_PHM_raw.csv
# YAKV_1PE_raw.csv  YAKV_2TI_raw.txt  YAKV_JAS_raw.csv  YAKV_PHM_raw.txt
# YAKV_1PE_raw.txt  YAKV_3JN_raw.csv  YAKV_JAS_raw.txt  YAKV_PHP_raw.csv
# YAKV_1TH_raw.csv  YAKV_3JN_raw.txt  YAKV_JHN_raw.csv  YAKV_PHP_raw.txt
# YAKV_1TH_raw.txt  YAKV_ACT_raw.csv  YAKV_JHN_raw.txt  YAKV_REV_raw.csv
# YAKV_1TI_raw.csv  YAKV_ACT_raw.txt  YAKV_JON_raw.csv  YAKV_REV_raw.txt
# YAKV_1TI_raw.txt  YAKV_COL_raw.csv  YAKV_JON_raw.txt  YAKV_ROM_raw.csv
# YAKV_2CO_raw.csv  YAKV_COL_raw.txt  YAKV_JUD_raw.csv  YAKV_ROM_raw.txt
# YAKV_2CO_raw.txt  YAKV_EPH_raw.csv  YAKV_JUD_raw.txt  YAKV_RUT_raw.csv
# YAKV_2JN_raw.csv  YAKV_EPH_raw.txt  YAKV_LUK_raw.csv  YAKV_RUT_raw.txt
# YAKV_2JN_raw.txt  YAKV_GAL_raw.csv  YAKV_LUK_raw.txt  YAKV_TIT_raw.csv
# YAKV_2PE_raw.csv  YAKV_GAL_raw.txt  YAKV_MAT_raw.csv  YAKV_TIT_raw.txt
#
# /content/data/unzipped/segmented/by_verse/Yami:
# SNT_1CO_raw.csv  SNT_2PE_raw.csv  SNT_GAL_raw.csv  SNT_MRK_raw.csv
# SNT_1CO_raw.txt  SNT_2PE_raw.txt  SNT_GAL_raw.txt  SNT_MRK_raw.txt
# SNT_1JN_raw.csv  SNT_2TH_raw.csv  SNT_HEB_raw.csv  SNT_PHM_raw.csv
# SNT_1JN_raw.txt  SNT_2TH_raw.txt  SNT_HEB_raw.txt  SNT_PHM_raw.txt
# SNT_1PE_raw.csv  SNT_2TI_raw.csv  SNT_JAS_raw.csv  SNT_PHP_raw.csv
# SNT_1PE_raw.txt  SNT_2TI_raw.txt  SNT_JAS_raw.txt  SNT_PHP_raw.txt
# SNT_1TH_raw.csv  SNT_3JN_raw.csv  SNT_JHN_raw.csv  SNT_REV_raw.csv
# SNT_1TH_raw.txt  SNT_3JN_raw.txt  SNT_JHN_raw.txt  SNT_REV_raw.txt
# SNT_1TI_raw.csv  SNT_ACT_raw.csv  SNT_JUD_raw.csv  SNT_ROM_raw.csv
# SNT_1TI_raw.txt  SNT_ACT_raw.txt  SNT_JUD_raw.txt  SNT_ROM_raw.txt
# SNT_2CO_raw.csv  SNT_COL_raw.csv  SNT_LUK_raw.csv  SNT_TIT_raw.csv
# SNT_2CO_raw.txt  SNT_COL_raw.txt  SNT_LUK_raw.txt  SNT_TIT_raw.txt
# SNT_2JN_raw.csv  SNT_EPH_raw.csv  SNT_MAT_raw.csv
# SNT_2JN_raw.txt  SNT_EPH_raw.txt  SNT_MAT_raw.txt

# %% [markdown]
# ## Cleaning and Preprocessing
#
# > write stuff

# %%
from src.cleaning_preprocessing import LanguageData

data_dir = os.path.join(unzipped_dir, "segmented/by_sentence")
languages = [language for language in os.listdir(data_dir)]

corpora = {}

for lang in languages:
  lang_path = os.path.join(data_dir, lang)
  lang_obj = LanguageData(lang, lang_path).load()
  corpora[lang] = lang_obj

  lang_obj.summary()
  print("-" * 40)
# Out:
# Language: Spanish
# No. of sentences: 34020
# Avg. word length: 4.30
# Avg. sentence length: 20.61
# ----------------------------------------
# Language: Isnag
# No. of sentences: 19884
# Avg. word length: 4.29
# Avg. sentence length: 15.74
# ----------------------------------------
# Language: Kalinga
# No. of sentences: 12050
# Avg. word length: 5.04
# Avg. sentence length: 15.79
# ----------------------------------------
# Language: Cebuano
# No. of sentences: 35191
# Avg. word length: 4.64
# Avg. sentence length: 23.23
# ----------------------------------------
# Language: Chavacano
# No. of sentences: 11889
# Avg. word length: 4.03
# Avg. sentence length: 23.56
# ----------------------------------------
# Language: Kankanaey
# No. of sentences: 20479
# Avg. word length: 4.88
# Avg. sentence length: 15.82
# ----------------------------------------
# Language: Tagalog
# No. of sentences: 51287
# Avg. word length: 4.89
# Avg. sentence length: 15.46
# ----------------------------------------
# Language: Tausug
# No. of sentences: 16055
# Avg. word length: 4.79
# Avg. sentence length: 16.80
# ----------------------------------------
# Language: Bikolano
# No. of sentences: 48739
# Avg. word length: 4.88
# Avg. sentence length: 17.28
# ----------------------------------------
# Language: Yami
# No. of sentences: 16269
# Avg. word length: 3.92
# Avg. sentence length: 15.18
# ----------------------------------------
# Language: Sambal
# No. of sentences: 12291
# Avg. word length: 4.82
# Avg. sentence length: 18.05
# ----------------------------------------
# Language: Pangasinense
# No. of sentences: 50736
# Avg. word length: 4.67
# Avg. sentence length: 16.30
# ----------------------------------------
# Language: Ivatan
# No. of sentences: 11183
# Avg. word length: 4.10
# Avg. sentence length: 22.98
# ----------------------------------------
# Language: Ilokano
# No. of sentences: 49843
# Avg. word length: 5.21
# Avg. sentence length: 12.92
# ----------------------------------------
# Language: Yakan
# No. of sentences: 16488
# Avg. word length: 5.32
# Avg. sentence length: 12.89
# ----------------------------------------
# Language: Kapampangan
# No. of sentences: 52492
# Avg. word length: 4.65
# Avg. sentence length: 16.66
# ----------------------------------------

# %% [markdown]
# ## Feature Engineering
# > write stuff

# %%
from src.feature_engineering import LanguageFeatureExtractor

char_ngram_n = 3 # @param {"type":"slider","min":1,"max":10,"step":1}
word_ngram_n = 1 # @param {"type":"slider","min":1,"max":5,"step":1}

feature_extractors = {}

for lang, lang_data in corpora.items():
  feat_extractor = LanguageFeatureExtractor(lang_data)
  feat_extractor.char_ngram(n=char_ngram_n)
  feat_extractor.word_ngram(n=word_ngram_n)
  feature_extractors[lang] = feat_extractor

  feat_extractor.summary()
  print("-" * 40)
# Out:
# Language: Spanish
# Avg. word length: 4.30
# Avg. sentence length: 20.61
#
# Top 20 character n-grams:
#  de: 58441
# os : 55816
# de : 45352
#  y : 29402
# el : 28550
# que: 27385
#  la: 25809
# ue : 25064
#  qu: 24545
# as : 23965
# es : 23142
# los: 21895
#  lo: 21776
# la : 21657
#  en: 21379
#  co: 21337
#  el: 21126
#  a : 20165
# s d: 19057
# en : 18796
#
# Top 20 word n-grams:
# de: 42778
# y: 32071
# a: 20507
# que: 20060
# la: 19185
# el: 18171
# los: 17232
# en: 15086
# no: 8087
# su: 7468
# se: 7412
# jehová: 6836
# por: 6765
# del: 6267
# con: 5859
# las: 5851
# para: 5831
# lo: 5463
# sus: 5006
# al: 4856
# ----------------------------------------
# Language: Isnag
# Avg. word length: 4.29
# Avg. sentence length: 15.74
#
# Top 20 character n-grams:
# ay : 28539
#  na: 26916
# ya : 24217
#  ka: 23068
# a n: 21696
# tu : 21187
# nga: 20310
#  ng: 20142
#  da: 19608
# án : 19131
# n n: 18012
# ga : 15659
# an : 14109
# na : 14000
#  ma: 13661
#  ki: 12834
# a k: 12735
# da : 11974
# a a: 10918
# _ay: 10475
#
# Top 20 word n-grams:
# ay: 19795
# nga: 14587
# na: 13840
# ya: 9865
# da: 8877
# se: 7268
# nu: 6466
# nán: 6084
# tu: 5747
# ka: 5643
# ne: 4776
# daya: 4688
# datu: 3946
# kitu: 3915
# pe: 3907
# kiya: 3705
# akkan: 3691
# ta: 3586
# dios: 3549
# ku: 2888
# ----------------------------------------
# Language: Kalinga
# Avg. word length: 5.04
# Avg. sentence length: 15.79
#
# Top 20 character n-grams:
# an : 25472
# un : 17435
#  ma: 16030
#  ka: 15527
#  na: 14008
#  si: 12691
#  di: 12582
#  da: 12315
#  un: 11885
# kan: 11456
# it : 10800
# at : 10246
# n d: 10234
# na : 9860
# ana: 9311
# dit: 8990
# man: 8336
# ang: 7821
# nan: 6701
# apu: 6422
#
# Top 20 word n-grams:
# un: 11788
# kan: 8784
# dit: 5576
# da: 4790
# si: 4317
# ot: 4022
# na: 3931
# dat: 3202
# apudyus: 2991
# nu: 2961
# yu: 2641
# ta: 2410
# jesus: 1902
# yoong: 1641
# di: 1639
# sit: 1558
# utdit: 1543
# tagu: 1534
# dan: 1430
# pay: 1345
# ----------------------------------------
# Language: Cebuano
# Avg. word length: 4.64
# Avg. sentence length: 23.23
#
# Top 20 character n-grams:
# ng : 112097
# sa : 108821
#  sa: 101099
# ang: 97182
# ga : 72362
#  ka: 67501
# nga: 56170
# an : 52734
# ug : 48880
#  ng: 46168
#  an: 45767
#  ug: 41760
# on : 35789
#  ma: 33032
#  na: 31854
# mga: 31262
#  mg: 31169
# a s: 30708
# ala: 30574
# a k: 30025
#
# Top 20 word n-grams:
# sa: 96601
# ug: 48870
# ang: 43130
# nga: 39389
# mga: 31257
# iyang: 10555
# ka: 9289
# si: 8783
# siya: 8325
# ginoo: 7229
# usa: 6908
# ni: 6681
# akong: 6025
# sila: 5946
# ako: 5515
# kay: 5511
# imong: 5333
# kini: 5197
# diha: 5186
# kaniya: 4921
# ----------------------------------------
# Language: Chavacano
# Avg. word length: 4.03
# Avg. sentence length: 23.56
#
# Top 20 character n-grams:
# el : 21122
#  co: 18112
#  el: 17530
#  ma: 14459
# con: 14130
# on : 13835
# ta : 12947
# ya : 12496
#  de: 12173
#  ya: 11610
# a c: 11567
#  di: 10905
# ga : 9723
# de : 9596
#  ta: 9540
#  si: 9273
# ra : 9222
# aga: 8851
# la : 8799
# mag: 8677
#
# Top 20 word n-grams:
# el: 15482
# ya: 12444
# con: 10961
# y: 8912
# maga: 8651
# ta: 7363
# di: 6447
# na: 5345
# de: 5007
# si: 4923
# del: 4607
# ustedes: 4439
# ay: 4162
# para: 3949
# que: 3859
# dios: 3328
# le: 3245
# gente: 2987
# yo: 2966
# sila: 2887
# ----------------------------------------
# Language: Kankanaey
# Avg. word length: 4.88
# Avg. sentence length: 15.82
#
# Top 20 character n-grams:
# an : 58744
# nan: 48873
# ay : 39582
#  na: 34927
#  ay: 28135
#  is: 21226
# en : 19960
#  ma: 19800
#  ka: 14726
# n a: 14693
# sna: 14607
# ang: 14562
# isn: 14470
# ken: 14296
#  da: 13515
# ana: 13216
# n n: 12392
# et : 11765
# da : 11119
# apo: 10969
#
# Top 20 word n-grams:
# ay: 28126
# nan: 28108
# isnan: 14138
# et: 10315
# ken: 9401
# apo: 6258
# ya: 5188
# siya: 4394
# dios: 4263
# tay: 4233
# di: 3678
# is: 3438
# dat: 3170
# en: 3011
# si: 2877
# ngem: 2736
# id: 2577
# no: 2547
# ipogaw: 2507
# daida: 2418
# ----------------------------------------
# Language: Tagalog
# Avg. word length: 4.89
# Avg. sentence length: 15.46
#
# Top 20 character n-grams:
# ng : 189124
# ang: 120780
#  sa: 61854
#  na: 57133
# sa : 56999
#  ka: 51279
#  an: 50502
#  ng: 46326
# at : 43261
# an : 40274
# g m: 36713
# ay : 36521
#  ma: 36018
#  ni: 33991
#  pa: 33470
# ala: 31116
# na : 29149
# ga : 29112
# a a: 27924
#  at: 27295
#
# Top 20 word n-grams:
# sa: 52571
# ang: 49551
# ng: 41956
# at: 27641
# na: 26058
# mga: 25937
# ay: 12916
# ni: 11549
# si: 7282
# hindi: 7093
# niya: 6145
# ito: 5832
# kanyang: 5732
# yahweh: 5628
# ko: 5416
# diyos: 5278
# siya: 4622
# mo: 4596
# nang: 4532
# lahat: 4396
# ----------------------------------------
# Language: Tausug
# Avg. word length: 4.79
# Avg. sentence length: 16.80
#
# Top 20 character n-grams:
# in : 37422
# an : 27199
#  si: 22661
#  ma: 22452
# ang: 20651
#  in: 20063
# iya: 19699
#  ka: 17403
# sin: 17140
# niy: 13730
#  na: 13309
# aꞌ : 13154
#  ni: 13006
#  ha: 12874
#  pa: 12625
# nga: 11219
# man: 11074
# ha : 10498
# n m: 10426
# ya : 10375
#
# Top 20 word n-grams:
# in: 19781
# sin: 17047
# ha: 10359
# manga: 7589
# na: 7538
# niya: 6261
# iban: 5074
# tau: 4575
# tuhan: 4405
# hi: 4330
# pa: 3857
# amu: 3502
# niyu: 3494
# nila: 3175
# ku: 3104
# dayn: 2898
# īsa: 2851
# siya: 2605
# kamu: 2470
# bang: 2169
# ----------------------------------------
# Language: Bikolano
# Avg. word length: 4.88
# Avg. sentence length: 17.28
#
# Top 20 character n-grams:
# an : 151851
#  sa: 98110
#  na: 80085
# ng : 73975
#  ka: 72091
# ang: 60139
#  ni: 54425
#  an: 54208
# na : 50399
# in : 49170
# sa : 48615
#  ma: 44512
# nin: 41544
# n s: 39162
# ga : 38750
# n m: 35409
# n n: 34380
# a s: 33938
# mga: 33376
#  mg: 32895
#
# Top 20 word n-grams:
# an: 56950
# na: 47226
# sa: 46675
# mga: 33170
# nin: 27038
# kan: 26944
# asin: 18644
# ni: 8887
# si: 8814
# dai: 8362
# kagurangnan: 7689
# niya: 7088
# siya: 6937
# ko: 6429
# sinda: 6357
# saiyang: 6254
# saka: 5865
# ako: 5734
# dios: 5593
# mo: 5163
# ----------------------------------------
# Language: Yami
# Avg. word length: 3.92
# Avg. sentence length: 15.18
#
# Top 20 character n-grams:
#  a : 18362
# na : 15820
# o a: 15060
#  am: 14866
#  na: 14089
# an : 13627
#  ka: 12978
# do : 12913
#  do: 12774
#  ta: 12516
# am : 12337
#  ma: 11481
# no : 11428
# so : 11167
# ng : 10997
# a n: 10056
#  ni: 10046
# ang: 9001
# ta : 8994
#  o : 8907
#
# Top 20 word n-grams:
# a: 18570
# do: 12773
# am: 11694
# na: 11516
# o: 10529
# no: 9676
# so: 8883
# ta: 7847
# da: 6064
# tao: 5306
# to: 5271
# ni: 5110
# ama: 4006
# rana: 3989
# ji: 3665
# si: 3553
# nyo: 3345
# ko: 3190
# yeso: 2594
# sira: 2392
# ----------------------------------------
# Language: Sambal
# Avg. word length: 4.82
# Avg. sentence length: 18.05
#
# Top 20 character n-grams:
# an : 29701
# ay : 20425
#  na: 17211
# in : 16056
#  a : 12937
#  ko: 12908
#  ka: 12869
#  ta: 12732
#  ma: 12452
#  ha: 11599
# on : 11290
# ang: 9861
# n a: 9581
# ha : 9336
#  ya: 9124
# nan: 8429
# na : 8301
#  pa: 8213
#  hi: 8075
# a k: 7914
#
# Top 20 word n-grams:
# a: 12939
# ha: 9326
# na: 5569
# ay: 4748
# yay: 4650
# nin: 4622
# ta: 3825
# nan: 3783
# tan: 3634
# dios: 3134
# kay: 2231
# ni: 2203
# main: 2160
# ko: 2126
# la: 2008
# jesus: 1975
# hilay: 1858
# kot: 1851
# moyo: 1807
# hi: 1770
# ----------------------------------------
# Language: Pangasinense
# Avg. word length: 4.67
# Avg. sentence length: 16.30
#
# Top 20 character n-grams:
# an : 112507
# ay : 69060
#  na: 52607
#  sa: 41965
#  ta: 40417
#  a : 39413
#  ka: 39380
# na : 37681
#  to: 36888
# tan: 36757
# ray: 36006
#  ma: 34549
# ara: 33470
# ang: 32121
#  si: 31509
# en : 30073
# n a: 29108
#  ed: 29086
# ed : 28945
#  pa: 26689
#
# Top 20 word n-grams:
# a: 39436
# na: 35798
# ed: 28886
# tan: 27838
# saray: 19340
# so: 18187
# to: 17788
# ya: 14911
# nen: 11733
# da: 10453
# ag: 9935
# say: 8320
# katawan: 7592
# iray: 7577
# ray: 7314
# diad: 7076
# et: 6586
# mo: 6466
# yo: 6298
# dios: 5945
# ----------------------------------------
# Language: Ivatan
# Avg. word length: 4.10
# Avg. sentence length: 22.98
#
# Top 20 character n-grams:
#  ka: 21174
#  a : 19375
# an : 18415
#  ma: 16348
# no : 15798
# o a: 15425
# a a: 15018
#  na: 14638
# do : 12803
#  o : 12137
#  no: 11847
# o k: 11807
#  do: 11689
# aya: 11015
#  di: 10872
# na : 10757
# a n: 10126
# a s: 9325
# a d: 8702
# a m: 8656
#
# Top 20 word n-grams:
# a: 19375
# no: 12594
# o: 12142
# do: 12107
# so: 7817
# as: 7476
# na: 7418
# am: 6099
# da: 5308
# sia: 4154
# sa: 3738
# ta: 3307
# aya: 3273
# nio: 3083
# dios: 3055
# ko: 2994
# mo: 2559
# kano: 2434
# ni: 2164
# pa: 2023
# ----------------------------------------
# Language: Ilokano
# Avg. word length: 5.21
# Avg. sentence length: 12.92
#
# Top 20 character n-grams:
# ti : 121426
# iti: 64699
#  ti: 57771
#  a : 53489
#  it: 36153
#  da: 34872
# agi: 34348
#  ka: 33918
# dag: 32682
# git: 31363
#  ke: 31316
# nga: 28738
# a a: 28669
#  ma: 27840
# an : 27730
# i a: 26903
#  na: 25168
# ang: 24343
# ada: 24321
# en : 23221
#
# Top 20 word n-grams:
# ti: 56432
# a: 53495
# iti: 36503
# dagiti: 19650
# nga: 19349
# ni: 17727
# ken: 14316
# ket: 12753
# kadagiti: 8158
# amin: 4660
# dios: 4552
# apo: 4547
# ngem: 4430
# no: 4301
# daytoy: 3412
# tattao: 3310
# ta: 3223
# adda: 3136
# kas: 3063
# ari: 2836
# ----------------------------------------
# Language: Yakan
# Avg. word length: 5.32
# Avg. sentence length: 12.89
#
# Top 20 character n-grams:
#  si: 18440
# eꞌ : 17024
# an : 15494
# si : 14886
# in : 14756
# aꞌa: 12909
#  ma: 11711
# ang: 11236
#  du: 10651
# aꞌ : 10614
#  ka: 10452
#  pa: 10332
# aꞌi: 10119
# iye: 8732
# han: 8677
# ne : 8655
# hin: 8016
# meꞌ: 7837
# uk : 7773
# duk: 7666
#
# Top 20 word n-grams:
# si: 13944
# meꞌ: 7835
# duk: 7606
# weꞌ: 5296
# iye: 4810
# ne: 4323
# kaꞌam: 3491
# siye: 3325
# isa: 2811
# tuhanin: 2797
# aꞌa: 2678
# bi: 2573
# bang: 2442
# gaꞌi: 2374
# inin: 2320
# niyaꞌ: 2247
# du: 2096
# saguwaꞌ: 2018
# peggeꞌ: 1990
# amban: 1721
# ----------------------------------------
# Language: Kapampangan
# Avg. word length: 4.65
# Avg. sentence length: 16.66
#
# Top 20 character n-grams:
# ng : 262588
# ing: 159237
# ang: 82954
# an : 73121
#  ka: 65993
#  na: 49332
# at : 46309
#  in: 42627
#  ma: 42336
# kin: 39543
# g m: 39475
#  ki: 38663
#  at: 35973
# na : 35921
# a k: 33591
# g k: 33331
# ung: 33131
# g a: 32533
# ala: 31720
#  pa: 30211
#
# Top 20 word n-grams:
# ing: 40589
# king: 37350
# na: 34698
# at: 32574
# ning: 25789
# a: 23395
# ding: 18083
# la: 16097
# ya: 15006
# e: 12130
# da: 12079
# nang: 10428
# ku: 10383
# karing: 9877
# mu: 8064
# i: 7524
# ginu: 6525
# ring: 6496
# dios: 6268
# lang: 5949
# ----------------------------------------

# %% [markdown]
# ## Clustering
# Continue here!!!
